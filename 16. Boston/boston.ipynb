# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('HousingData.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.shape
# Out:
# (506, 14)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in df.columns:
    meaned = df[col].mean()
    df[col].fillna(meaned, inplace=True)
# Out:
# C:\Users\korez\AppData\Local\Temp\ipykernel_17124\3426908753.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(meaned, inplace=True)

# %%
df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
for col in df.columns:
    sns.boxplot(df[col])
    plt.show()

# %%
sns.barplot(df)
plt.show()

# %%
for col in df.columns:
    sns.displot(df[col])
    plt.show()

# %%
df['CHAS'].unique()
# Out:
# array([0.        , 0.06995885, 1.        ])

# %%
df['CHAS'] = df['CHAS'].apply(lambda x: 0 if x < 1 else 1)

# %%
df['CHAS'].unique()
# Out:
# array([0, 1])

# %%
plt.figure(figsize=(21,7))
plt.plot(df['MEDV'])
plt.show()

# %%
for col in df.columns:
    plt.figure(figsize=(20,5))
    sns.scatterplot(x=df[col], y=df['MEDV'])
    plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %% [markdown]
# dummy crim, zn, chas, dis, b

# %%
dummy_df = df[['CRIM', 'ZN','DIS', 'B']] # , 'PTRATIO', 'RAD','TAX'
dummy_df
# Out:
#         CRIM    ZN     DIS       B
# 0    0.00632  18.0  4.0900  396.90
# 1    0.02731   0.0  4.9671  396.90
# 2    0.02729   0.0  4.9671  392.83
# 3    0.03237   0.0  6.0622  394.63
# 4    0.06905   0.0  6.0622  396.90
# ..       ...   ...     ...     ...
# 501  0.06263   0.0  2.4786  391.99
# 502  0.04527   0.0  2.2875  396.90
# 503  0.06076   0.0  2.1675  396.90
# 504  0.10959   0.0  2.3889  393.45
# 505  0.04741   0.0  2.5050  396.90
#
# [506 rows x 4 columns]

# %%
for col in dummy_df.columns:
    meds = dummy_df[col].median()
    df[col] = df[col].apply(lambda x : 1 if x > meds else 0) # 1 = high |  0 = low

# %%
for col in df.columns:
    plt.figure(figsize=(20,5))
    sns.scatterplot(x=df[col], y=df['MEDV'])
    plt.show()

# %%
x = df.drop(columns='MEDV')
target = df['MEDV']

# %%
dff = df.drop(columns='CHAS')

# %%
for col in dff.columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3-Q1
    lwr = Q1 - IQR * 2.5
    upr = Q3 + IQR * 2.5
    
    df[col].loc[(df[col] <= lwr) | (df[col] >= upr)] = df[col].median()
# Out:
# C:\Users\korez\AppData\Local\Temp\ipykernel_17124\3333112005.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[col].loc[(df[col] <= lwr) | (df[col] >= upr)] = df[col].median()
# ...

# %%
x_cat = df[['B', 'CHAS', 'CRIM', 'DIS', 'ZN', 'MEDV', 'PTRATIO','TAX', 'RAD']]
x_num = df.drop(columns=['B', 'CHAS', 'CRIM', 'DIS', 'ZN', 'PTRATIO' ,'TAX', 'RAD'])

# %%
for col in x_cat.columns:
    sns.boxplot(x=x_cat[col],y=target)
    plt.show()

# %%
sns.pairplot(x_num)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
x = x.drop(columns=['B','CHAS','RAD'])

# %%
def minmax(input):
    minim = input.min()
    maxim = input.min()
    scaler = (input - minim) / (maxim - minim)
    return scaler, minim, maxim

# %%
def strat(x,y,training = 0.8):
    np.random.seed(42)
    yidx = {}
    for i, label in enumerate(y):
        if label not in yidx:
            yidx[label] = [i]
        else:
            yidx[label].append(i)
            
    tr = []
    te = []
    
    for i,label in yidx.items():
        shuffle = np.random.permutation(label)
        train = max(1, int(len(shuffle) * training))
        tr.extend(shuffle[:train])
        te.extend(shuffle[train:])
        
    xtr = x.iloc[tr].reset_index(drop=True)
    xte = x.iloc[te].reset_index(drop=True)
    ytr = y.iloc[tr].reset_index(drop=True)
    yte = y.iloc[te].reset_index(drop=True)
    
    return xtr,xte,ytr,yte

# %%
xtr,xte,ytr,yte = strat(x,target,training=0.7)

# %%
print(xtr.shape)
print(xte.shape)
print(ytr.shape)
print(yte.shape)
# Out:
# (330, 10)
# (176, 10)
# (330,)
# (176,)

# %%
xtr
# Out:
#      CRIM  ZN  INDUS    NOX     RM   AGE  DIS  TAX  PTRATIO  LSTAT
# 0       1   0   6.20  0.507  6.086  61.5    1  307     17.4  10.88
# 1       0   0   7.07  0.469  6.421  78.9    1  242     17.8   9.14
# 2       0   0   7.07  0.469  7.185  61.1    1  242     17.8   4.03
# 3       0   1   2.18  0.472  7.420  71.9    0  222     18.4   6.47
# 4       0   0   2.46  0.488  6.144  62.2    0  193     17.8   9.45
# ..    ...  ..    ...    ...    ...   ...  ...  ...      ...    ...
# 325     1   0  18.10  0.713  6.701  90.0    0  666     20.2  16.42
# 326     1   0  18.10  0.713  6.376  88.4    0  666     20.2  14.65
# 327     1   0  18.10  0.614  5.304  97.3    0  666     20.2  24.91
# 328     1   0  18.10  0.532  5.762  40.3    1  666     20.2  10.42
# 329     0   0  27.74  0.609  5.093  98.0    0  711     20.1  29.68
#
# [330 rows x 10 columns]

# %% [markdown]
# Preprocessing:
# 1. Nan diganti mean
# 2. Outlier diganti mean
# 3. Dummy variable bisa di cek di dummy_df
# 4. stratified split, normalisasi
# 5. ada x_num, x_cat, sama x, yang di strat buat regresi yang x
# 6. x_num, x_cat dipakek buat cari tau variabel apa aja yg  di drop (drop variabel B, CHAS)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

model = LinearRegression()
model.fit(xtr,ytr)
# Out:
# LinearRegression()

# %%
ypred = model.predict(xte)

# %%
mse = mean_squared_error(yte, ypred)  # Mean Squared Error
r2 = r2_score(yte, ypred)  # R² Score

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(F'rmse = {np.sqrt(mse):.2f}')
print(f"R² Score: {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 15.41
# rmse = 3.92
# R² Score: 0.52

# %%
import joblib

# Save the trained model to a file
joblib.dump(model, "boston_housing_model.pkl")
# Out:
# ['boston_housing_model.pkl']

# %%
1630 / 0.5
# Out:
# 3260.0
