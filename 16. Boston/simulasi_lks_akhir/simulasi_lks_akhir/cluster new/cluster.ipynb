# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('HousingData.csv')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.isna().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (394, 14)

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  394.000000  394.000000  394.000000  394.000000  394.000000  394.000000
# mean     3.690136   11.460660   11.000863    0.068528    0.553215    6.280015
# std      9.202423   23.954082    6.908364    0.252971    0.113112    0.697985
# min      0.006320    0.000000    0.460000    0.000000    0.389000    3.561000
# 25%      0.081955    0.000000    5.130000    0.000000    0.453000    5.879250
# 50%      0.268880    0.000000    8.560000    0.000000    0.538000    6.201500
# 75%      3.435973   12.500000   18.100000    0.000000    0.624000    6.605500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  394.000000  394.000000  394.000000  394.000000  394.000000  394.000000
# mean    68.932741    3.805268    9.403553  406.431472   18.537563  358.490939
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in df.columns:
    sns.boxplot(df[col])
    plt.show()

# %%
df['MEDV'] = df['MEDV'].apply(lambda x: 1 if x > 25 else 0) # mahal = 1 murah = 0
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98     0
# 1  396.90   9.14     0
# 2  392.83   4.03     1
# 3  394.63   2.94     1
# 5  394.12   5.21     1

# %%
for col in df.columns:
    sns.histplot(df[col])
    plt.show()

# %% [markdown]
# dummy material: Crim, Nox, Age, Dis, B (TAX n ZN n RAD maybe)

# %%
dummy_subject = df[['CRIM','NOX','RM','B','TAX','LSTAT']]

for idx in dummy_subject:
    df[f'{idx}_d'] = df[idx].apply(lambda x: 1 if x > df[idx].mean() else 0) # 1 = high & 0 = low

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV  CRIM_d  NOX_d  RM_d  B_d  TAX_d  LSTAT_d
# 0  396.90   4.98     0       0      0     1    1      0        0
# 1  396.90   9.14     0       0      0     1    1      0        0
# 2  392.83   4.03     1       0      0     1    1      0        0
# 3  394.63   2.94     1       0      0     1    1      0        0
# 5  394.12   5.21     1       0      0     1    1      0        0

# %%
df['ZN_d'] = df['ZN'].apply(lambda x: 0 if x == 0 else 1) # 0 = no & 1 = yes
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  ...  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296  ...
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242  ...
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242  ...
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222  ...
# 5  0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222  ...
#
#         B  LSTAT  MEDV  CRIM_d  NOX_d  RM_d  B_d  TAX_d  LSTAT_d  ZN_d
# 0  396.90   4.98     0       0      0     1    1      0        0     1
# 1  396.90   9.14     0       0      0     1    1      0        0     0
# 2  392.83   4.03     1       0      0     1    1      0        0     0
# 3  394.63   2.94     1       0      0     1    1      0        0     0
# 5  394.12   5.21     1       0      0     1    1      0        0     0
#
# [5 rows x 21 columns]

# %%
df['ZN'].value_counts()
# Out:
# ZN
# 0.0      291
# 20.0      17
# 25.0      10
# 80.0      10
# 22.0       9
# 12.5       8
# 90.0       5
# 45.0       4
# 95.0       4
# 40.0       4
# 33.0       3
# 30.0       3
# 60.0       3
# 75.0       3
# 70.0       3
# 21.0       2
# 85.0       2
# 52.5       2
# 55.0       2
# 28.0       2
# 82.5       2
# 35.0       2
# 18.0       1
# 100.0      1
# 17.5       1
# Name: count, dtype: int64

# %%
for col in df.columns:
    sns.boxplot(x=df['MEDV'], y=df[col])
    plt.show()

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  ...  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296  ...
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242  ...
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242  ...
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222  ...
# 5  0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222  ...
#
#         B  LSTAT  MEDV  CRIM_d  NOX_d  RM_d  B_d  TAX_d  LSTAT_d  ZN_d
# 0  396.90   4.98     0       0      0     1    1      0        0     1
# 1  396.90   9.14     0       0      0     1    1      0        0     0
# 2  392.83   4.03     1       0      0     1    1      0        0     0
# 3  394.63   2.94     1       0      0     1    1      0        0     0
# 5  394.12   5.21     1       0      0     1    1      0        0     0
#
# [5 rows x 21 columns]

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
df.drop(columns=['CHAS', 'RAD'],inplace=True)

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
df['MEDV'].value_counts()
# Out:
# MEDV
# 0    300
# 1     94
# Name: count, dtype: int64

# %%
minor = df[df['MEDV'] == 1]
major = df[df['MEDV'] == 0]
class_size = 300

minor_scaled = minor.sample(class_size,replace=True)
df_scaled = pd.concat([minor_scaled,major],ignore_index=True)
df = df_scaled.sample(frac=1,random_state=42).reset_index(drop=True)

# %%
df['MEDV'].value_counts()
# Out:
# MEDV
# 1    300
# 0    300
# Name: count, dtype: int64

# %%
x = df.drop(columns='MEDV')
y = df['MEDV']

# %%
def strat(x,y,train_size:0.8):
    np.random.seed(42)
    yidx = {}
    for idx,label in enumerate(y):
        if label not in yidx:
            yidx[label] = [idx]
        else:
            yidx[label].append(idx)
            
    trbox = []
    tebox = []
    
    for idx,label in yidx.items():
        shuffle = np.random.permutation(label)
        train = max(1,int(len(shuffle) * train_size))
        trbox.extend(shuffle[:train])
        tebox.extend(shuffle[train:])
        
    xtr = x.iloc[trbox].reset_index(drop=True)
    xte = x.iloc[tebox].reset_index(drop=True)
    ytr = y.iloc[trbox].reset_index(drop=True)
    yte = y.iloc[tebox].reset_index(drop=True)
    
    print(ytr.value_counts())
    print(yte.value_counts())
    
    return xtr,xte,ytr,yte

# %%
xtr,xte,ytr,yte = strat(x,y,train_size=0.8)
# Out:
# MEDV
# 1    240
# 0    240
# Name: count, dtype: int64
# MEDV
# 1    60
# 0    60
# Name: count, dtype: int64

# %%
print(xtr.shape)
print(xte.shape)
print(ytr.shape)
print(yte.shape)
# Out:
# (480, 18)
# (120, 18)
# (480,)
# (120,)

# %%
def minmax(input):
    minim = input.min()
    maxim = input.max()
    scaled = (input - minim) / (maxim - minim)
    return scaled,minim,maxim

# %%
xtrs, minim, maxim = minmax(xtr)
xtes = (xte - minim) / (maxim - minim)

# %%
from sklearn.svm import SVC

svm = SVC(kernel='rbf')
svm.fit(xtrs,ytr)
ypred_svm = svm.predict(xtes)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=42,n_estimators=100)
rf.fit(xtrs,ytr)
ypred_rf = rf.predict(xtes)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(yte,ypred_svm))
print(classification_report(yte,ypred_svm))
print(np.mean(yte == ypred_svm) * 100)
# Out:
# [[53  7]
#  [ 7 53]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        60
#            1       0.88      0.88      0.88        60
#
#     accuracy                           0.88       120
#    macro avg       0.88      0.88      0.88       120
# weighted avg       0.88      0.88      0.88       120
#
# 88.33333333333333

# %%
print(confusion_matrix(yte,ypred_rf))
print(classification_report(yte,ypred_rf))
print(np.mean(yte == ypred_rf) * 100)
# Out:
# [[59  1]
#  [ 0 60]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        60
#            1       0.98      1.00      0.99        60
#
#     accuracy                           0.99       120
#    macro avg       0.99      0.99      0.99       120
# weighted avg       0.99      0.99      0.99       120
#
# 99.16666666666667
