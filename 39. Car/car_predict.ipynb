# %% [markdown]
# # **Car Price Dataset**

# %% [markdown]
# **Nama : Muhammad Shofian Najib & Davino Edric**
#
# **Sekolah : SMK Negeri I Surabaya**
#
# **No Peserta :**

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **A. Exploratory Data Analysis**

# %%
df = pd.read_csv('CarPrice_Assignment.csv')
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %% [markdown]
# ## **A.1 Dimensi dataset**

# %%
df.shape
# Out:
# (205, 26)

# %% [markdown]
# **205 baris** dan **26 kolom**

# %% [markdown]
# ## **A.2 Info dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# - **Kolom objek** : 10 kolom
# - **Kolom float** : 8 kolom
# - **Kolom integer** : 8 kolom

# %% [markdown]
# ## **A.3 Pengecekan nilai hilang**

# %%
df.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# **Tidak ada nilai hilang**

# %% [markdown]
# ## **A.4 Pengecekan data duplikat**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Tidak ada data duplikat**

# %% [markdown]
# ## **A.5 Menghapus Kolom car_ID**

# %%
df.drop(columns='car_ID', inplace=True)

# %% [markdown]
# **Menghapus kolom car_ID karena tidak penting**

# %% [markdown]
# ## **A.6 Membuat num_cols**

# %%
num_cols = df.select_dtypes(include=np.number)
num_cols
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0            3       88.6      168.8      64.1       48.8        2548
# 1            3       88.6      168.8      64.1       48.8        2548
# 2            1       94.5      171.2      65.5       52.4        2823
# 3            2       99.8      176.6      66.2       54.3        2337
# 4            2       99.4      176.6      66.4       54.3        2824
# ..         ...        ...        ...       ...        ...         ...
# 200         -1      109.1      188.8      68.9       55.5        2952
# 201         -1      109.1      188.8      68.8       55.5        3049
# 202         -1      109.1      188.8      68.9       55.5        3012
# 203         -1      109.1      188.8      68.9       55.5        3217
# 204         -1      109.1      188.8      68.9       55.5        3062
#
#      enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# ...

# %% [markdown]
# ## **A.7 Statistik deskriptif**

# %%
round(num_cols.describe(), 2)
# Out:
#        symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# count     205.00     205.00     205.00    205.00     205.00      205.00
# mean        0.83      98.76     174.05     65.91      53.72     2555.57
# std         1.25       6.02      12.34      2.15       2.44      520.68
# min        -2.00      86.60     141.10     60.30      47.80     1488.00
# 25%         0.00      94.50     166.30     64.10      52.00     2145.00
# 50%         1.00      97.00     173.20     65.50      54.10     2414.00
# 75%         2.00     102.40     183.10     66.90      55.50     2935.00
# max         3.00     120.90     208.10     72.30      59.80     4066.00
#
#        enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# count      205.00     205.00  205.00            205.00      205.00   205.00
# mean       126.91       3.33    3.26             10.14      104.12  5125.12
# std         41.64       0.27    0.31              3.97       39.54   476.99
# ...

# %% [markdown]
# Insight yang bisa didapatkan yaitu :
# - **Mean**
# - **Standar Deviasi**
# - **Median**
# - **Q1 dan Q3**

# %% [markdown]
# ### **A.7.1 Range**

# %%
for col in num_cols:
    range_val = num_cols[col].max() - num_cols[col].min()
    print(f'Range Kolom {col} : {round(range_val, 2)}')
# Out:
# Range Kolom symboling : 5
# Range Kolom wheelbase : 34.3
# Range Kolom carlength : 67.0
# Range Kolom carwidth : 12.0
# Range Kolom carheight : 12.0
# Range Kolom curbweight : 2578
# Range Kolom enginesize : 265
# Range Kolom boreratio : 1.4
# Range Kolom stroke : 2.1
# Range Kolom compressionratio : 16.0
# Range Kolom horsepower : 240
# Range Kolom peakrpm : 2450
# Range Kolom citympg : 36
# Range Kolom highwaympg : 38
# Range Kolom price : 40282.0

# %% [markdown]
# ### **A.7.2 Interquartile Range**

# %%
for col in num_cols:
    iqr = num_cols[col].quantile(0.75) - num_cols[col].quantile(0.25)
    print(f'Interquatile Range Kolom {col} : {round(iqr, 2)}')
# Out:
# Interquatile Range Kolom symboling : 2.0
# Interquatile Range Kolom wheelbase : 7.9
# Interquatile Range Kolom carlength : 16.8
# Interquatile Range Kolom carwidth : 2.8
# Interquatile Range Kolom carheight : 3.5
# Interquatile Range Kolom curbweight : 790.0
# Interquatile Range Kolom enginesize : 44.0
# Interquatile Range Kolom boreratio : 0.43
# Interquatile Range Kolom stroke : 0.3
# Interquatile Range Kolom compressionratio : 0.8
# Interquatile Range Kolom horsepower : 46.0
# Interquatile Range Kolom peakrpm : 700.0
# Interquatile Range Kolom citympg : 11.0
# Interquatile Range Kolom highwaympg : 9.0
# Interquatile Range Kolom price : 8715.0

# %% [markdown]
# ### **A.7.3 Variansi**

# %%
for col in num_cols:
    variance = num_cols[col].var()
    print(f'Variansi Kolom {col} : {round(variance, 2)}')
# Out:
# Variansi Kolom symboling : 1.55
# Variansi Kolom wheelbase : 36.26
# Variansi Kolom carlength : 152.21
# Variansi Kolom carwidth : 4.6
# Variansi Kolom carheight : 5.97
# Variansi Kolom curbweight : 271107.87
# Variansi Kolom enginesize : 1734.11
# Variansi Kolom boreratio : 0.07
# Variansi Kolom stroke : 0.1
# Variansi Kolom compressionratio : 15.78
# Variansi Kolom horsepower : 1563.74
# Variansi Kolom peakrpm : 227515.3
# Variansi Kolom citympg : 42.8
# Variansi Kolom highwaympg : 47.42
# Variansi Kolom price : 63821761.58

# %% [markdown]
# ## **A.8 Histogram dan Boxplot**

# %%
for col in num_cols:
    fig, axes = plt.subplots(1, 2, figsize=(10, 5))

    sns.histplot(num_cols[col], kde=True, ax=axes[0])
    axes[0].set_title(f'Histogram {col}')

    sns.boxplot(num_cols[col], ax=axes[1])
    axes[1].set_title(f'Boxplot {col}')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# - **Terdapat beberapa kolom yang distribusinya miring**
# - **Terdapat juga beberapa kolom yang memiliki outlier**

# %% [markdown]
# ## **A.9 Kolom price vs num_cols**

# %%
for col in num_cols.columns:
  if col != 'price':
    sns.lmplot(data=num_cols, x=col, y='price', height=5, aspect=1.5, line_kws={'color': 'red'})
    plt.title(f'Scatterplot {col} vs Price with Linear Fit')
    plt.show()

# %% [markdown]
# Kolom yang linear positif dengan kolom price :
# - **wheelbase**
# - **carlength**
# - **carwidth**
# - **carheight**
# - **curbweight**
# - **enginesize**
# - **boreratio**
# - **horsepower**

# %% [markdown]
# Kolom yang linear negatif dengan kolom price :
# - **citympg**
# - **highwaympg**

# %% [markdown]
# ## **A.10 Outlier**

# %% [markdown]
# ### **Outlier dengan Interquartile Range**

# %%
outlier_iqr = {}
for col in num_cols:
    q1 = num_cols[col].quantile(0.25)
    q3 = num_cols[col].quantile(0.75)
    iqr = q3 - q1
    lwr = q1 - 1.5 * iqr
    upr = q3 + 1.5 * iqr
    outlier_iqr[col] = num_cols[col][(num_cols[col] < lwr) | (num_cols[col] > upr)].shape[0]

outlier_iqr
# Out:
# {'symboling': 0,
#  'wheelbase': 3,
#  'carlength': 1,
#  'carwidth': 8,
#  'carheight': 0,
#  'curbweight': 0,
#  'enginesize': 10,
#  'boreratio': 0,
#  'stroke': 20,
#  'compressionratio': 28,
#  'horsepower': 6,
#  'peakrpm': 2,
#  'citympg': 2,
#  'highwaympg': 3,
#  'price': 15}

# %% [markdown]
# ### **Outlier dengan Z-Score**

# %%
outlier_z = {}
for col in num_cols:
    z = (num_cols[col] - num_cols[col].mean()) / num_cols[col].std()
    outlier_z[col] = z[(z < -3) | (z > 3)].shape[0]

outlier_z
# Out:
# {'symboling': 0,
#  'wheelbase': 1,
#  'carlength': 0,
#  'carwidth': 0,
#  'carheight': 0,
#  'curbweight': 0,
#  'enginesize': 5,
#  'boreratio': 0,
#  'stroke': 3,
#  'compressionratio': 9,
#  'horsepower': 2,
#  'peakrpm': 2,
#  'citympg': 3,
#  'highwaympg': 2,
#  'price': 3}

# %% [markdown]
# ## **A.11 Kolom price dan Kolom symboling**

# %%
sns.boxplot(x=num_cols['symboling'], y=num_cols['price'])
plt.show()

# %% [markdown]
# - Mobil yang skor risiko asuransi -2 memiliki harga yang tinggi karena mungkin risikonya yang paling rendah.

# %% [markdown]
# ## **A.12 Korelasi Antarkolom**

# %% [markdown]
# ## **Korelasi Spearman**

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(num_cols.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %% [markdown]
# Kolom yang berkorelasi tinggi dengan target (price) :
# - **horsepower** (0.81)
# - **enginesize** (0.87)
# - **curbweight** (0.84)

# %% [markdown]
# ## **A.13 Membuat kolom brand**

# %%
df['brand'] = df['CarName'].str.extract(r'^([A-Za-z0-9\-\_]+)s*')
df.drop(columns='CarName', inplace=True)

# %% [markdown]
# ## **A.14 Nilai unik pada kolom brand**

# %%
df['brand'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %% [markdown]
# **Ada kejanggalan dalam nama brand di dataset**

# %% [markdown]
# ## **A.14 Menangani kejanggalan di kolom brand**

# %%
map_brand = {
    'toyouta': 'toyota',
    'Nissan': 'nissan',
    'maxda': 'mazda',
    'porcshce': 'porsche',
    'vw': 'volkswagen',
    'vokswagen': 'volkswagen',
    'alfa-romero': 'alfa-romeo',
    'Nissan': 'nissan',
}
df['brand'] = df['brand'].replace(map_brand)
df['brand'].unique()
# Out:
# array(['alfa-romeo', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %% [markdown]
# ## **A.15 Pengecekan data hilang di kolom brand**

# %%
df['brand'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## **A.16 Melakukan mapping kolom brand sesuai dengan seberapa tinggi rata-rata nilainya dengan price (Estimated Brand Value (EBV))**

# %%
brand_val = df.groupby('brand')['price'].mean().sort_values().index
brand_val
# Out:
# Index(['chevrolet', 'dodge', 'plymouth', 'honda', 'subaru', 'isuzu',
#        'mitsubishi', 'renault', 'toyota', 'volkswagen', 'nissan', 'mazda',
#        'saab', 'peugeot', 'alfa-romeo', 'mercury', 'audi', 'volvo', 'bmw',
#        'porsche', 'buick', 'jaguar'],
#       dtype='object', name='brand')

# %%
brand_val_dicto = {label: idx for idx,label in enumerate(brand_val)}
brand_val_dicto
df['brand'] =  df['brand'].map(brand_val_dicto)

# %%
cat_col = df.select_dtypes(include='object')
cat_col
# Out:
#     fueltype aspiration doornumber      carbody drivewheel enginelocation  \
# 0        gas        std        two  convertible        rwd          front
# 1        gas        std        two  convertible        rwd          front
# 2        gas        std        two    hatchback        rwd          front
# 3        gas        std       four        sedan        fwd          front
# 4        gas        std       four        sedan        4wd          front
# ..       ...        ...        ...          ...        ...            ...
# 200      gas        std       four        sedan        rwd          front
# 201      gas      turbo       four        sedan        rwd          front
# 202      gas        std       four        sedan        rwd          front
# 203   diesel      turbo       four        sedan        rwd          front
# 204      gas      turbo       four        sedan        rwd          front
#
#     enginetype cylindernumber fuelsystem
# ...

# %% [markdown]
# ## **A.17 Distribusi kolom kategorikal**

# %%
for col in cat_col:
    if col != 'brand':
      sns.countplot(data=df, x=col, hue=col, order=cat_col[col].value_counts().index)
      plt.ylabel('Frekuensi')
      plt.xticks(rotation=45)
      plt.show()

# %% [markdown]
# ## **A.18 Distribusi kolom brand**

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, y='brand', order=df['brand'].value_counts().index, hue='brand', orient='h')
plt.xlabel('Frekuensi')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## **A.19 Kolom price vs kolom kategorikal**

# %%
for col in df.select_dtypes(include='object'):
    if col != 'brand':
      sns.boxplot(x=col, y='price', data=df)
      plt.xticks(rotation=45)
      plt.show()

# %% [markdown]
# ## **A.20 Kolom price vs kolom brand**

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(y='brand', x='price', data=df, orient='h')
plt.show()

# %% [markdown]
# ## **A.20 Kolom brand vs beberapa kolom**

# %%
for col in df[['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight', 'enginesize', 'boreratio', 'horsepower']]:
    sns.boxplot(data=df, x=col, y='brand', orient='h')
    plt.show()

# %%
for col in df[['citympg', 'highwaympg']]:
    sns.boxplot(data=df, x=col, y='brand', orient='h')
    plt.show()

# %% [markdown]
# # **B. Pre-processing Data**

# %% [markdown]
# ## **B.1 Pengelompokkan kolom price**

# %%
print(f'Harga rendah : {df['price'].min()} - {df['price'].median()}')
print(f'Harga tinggi : {df['price'].median()} - {df['price'].max()}')
# Out:
# Harga rendah : 5118.0 - 10295.0
# Harga tinggi : 10295.0 - 45400.0

# %%
med = df['price'].median()
def classify(price):
    if price <= med:
        return 'Murah'
    else:
        return 'Mahal'
    
df['price'] = df['price'].apply(classify)

# %%
df['price'].value_counts()
# Out:
# price
# Murah    103
# Mahal    102
# Name: count, dtype: int64

# %% [markdown]
# ## **B.2 Visualisasi kolom price**

# %%
sns.countplot(data=df, x='price', order=df['price'].value_counts().index, hue='price')
plt.show()

# %% [markdown]
# ## **B.3 Menangani outlier**

# %%
for col in df.select_dtypes(include='number'):
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lwr = q1 - 1.5 * iqr
    upr = q3 + 1.5 * iqr
    df[col] = df[col].apply(lambda x: df[col].median() if x < lwr or x > upr else x)
    outlier_iqr[col] = df[col][(df[col] < lwr) | (df[col] > upr)].shape[0]

outlier_iqr
# Out:
# {'symboling': 0,
#  'wheelbase': 0,
#  'carlength': 0,
#  'carwidth': 0,
#  'carheight': 0,
#  'curbweight': 0,
#  'enginesize': 0,
#  'boreratio': 0,
#  'stroke': 0,
#  'compressionratio': 0,
#  'horsepower': 0,
#  'peakrpm': 0,
#  'citympg': 0,
#  'highwaympg': 0,
#  'price': 15,
#  'brand': 0}

# %%
df['price'] = df['price'].map({'Murah': 0, 'Mahal': 1})

# %%
df['price'].value_counts()
# Out:
# price
# 0    103
# 1    102
# Name: count, dtype: int64

# %% [markdown]
# ## **B.4 Mapping pada kolom kategorikal**

# %%
mapping = {}
for col in df.select_dtypes(include='object'):
    mapping[col] = {k: v for v, k in enumerate(df[col].unique())}
    df[col] = df[col].map(mapping[col])

mapping
# Out:
# {'fueltype': {'gas': 0, 'diesel': 1},
#  'aspiration': {'std': 0, 'turbo': 1},
#  'doornumber': {'two': 0, 'four': 1},
#  'carbody': {'convertible': 0,
#   'hatchback': 1,
#   'sedan': 2,
#   'wagon': 3,
#   'hardtop': 4},
#  'drivewheel': {'rwd': 0, 'fwd': 1, '4wd': 2},
#  'enginelocation': {'front': 0, 'rear': 1},
#  'enginetype': {'dohc': 0,
#   'ohcv': 1,
#   'ohc': 2,
#   'l': 3,
#   'rotor': 4,
#   'ohcf': 5,
#   'dohcv': 6},
#  'cylindernumber': {'four': 0,
#   'six': 1,
#   'five': 2,
#   'three': 3,
#   'twelve': 4,
#   'two': 5,
#   'eight': 6},
#  'fuelsystem': {'mpfi': 0,
#   '2bbl': 1,
#   'mfi': 2,
#   '1bbl': 3,
#   'spfi': 4,
#   '4bbl': 5,
#   'idi': 6,
#   'spdi': 7}}

# %% [markdown]
# ## **B.5 One-Hot Encoding**

# %%
df = pd.get_dummies(df, columns=['fueltype', 'aspiration', 'doornumber', 'drivewheel', 'enginelocation'], drop_first=True).astype('int64')
df.columns
# Out:
# Index(['symboling', 'carbody', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
#        'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price', 'brand', 'fueltype_1',
#        'aspiration_1', 'doornumber_1', 'drivewheel_1', 'drivewheel_2',
#        'enginelocation_1'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# symboling           0
# carbody             0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# brand               0
# fueltype_1          0
# aspiration_1        0
# doornumber_1        0
# drivewheel_1        0
# drivewheel_2        0
# enginelocation_1    0
# dtype: int64

# %% [markdown]
# ## **B.6 Menghapus data duplikat**

# %%
df.duplicated().sum()
# Out:
# np.int64(7)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## **B.7 Korelasi**

# %%
plt.figure(figsize=(16, 12))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %% [markdown]
# ## **B.8 Korelasi**

# %%
x = df[['brand', 'carbody', 'cylindernumber', 'enginesize', 'horsepower', 'curbweight', 'fueltype_1', 'drivewheel_1', 'drivewheel_2', 'citympg', 'highwaympg']]
y = df['price']

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 198 entries, 0 to 204
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   brand           198 non-null    int64
#  1   carbody         198 non-null    int64
#  2   cylindernumber  198 non-null    int64
#  3   enginesize      198 non-null    int64
#  4   horsepower      198 non-null    int64
#  5   curbweight      198 non-null    int64
#  6   fueltype_1      198 non-null    int64
#  7   drivewheel_1    198 non-null    int64
#  8   drivewheel_2    198 non-null    int64
#  9   citympg         198 non-null    int64
#  10  highwaympg      198 non-null    int64
# dtypes: int64(11)
# memory usage: 18.6 KB

# %%
def train_test_split(x, y, test_size=0.2, stratify=None, random_state=None):
    np.random.seed(random_state)
    
    x = np.array(x)
    y = np.array(y)
    
    if stratify is not None:
        unique_classes, y_indices = np.unique(stratify, return_inverse=True)
        test_indices = np.array([], dtype=int)
        train_indices = np.array([], dtype=int)
        
        for class_index in range(len(unique_classes)):
            class_indices = np.where(y_indices == class_index)[0]
            np.random.shuffle(class_indices)
            
            n_test = int(len(class_indices) * test_size)
            test_indices = np.concatenate((test_indices, class_indices[:n_test]))
            train_indices = np.concatenate((train_indices, class_indices[n_test:]))
    else:
        indices = np.arange(len(y))
        np.random.shuffle(indices)
        
        n_test = int(len(y) * test_size)
        test_indices = indices[:n_test]
        train_indices = indices[n_test:]
    
    x_train, x_test = x[train_indices], x[test_indices]
    y_train, y_test = y[train_indices], y[test_indices]
    
    return x_train, x_test, y_train, y_test

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=42)
print(f'Jumlah x_train : {x_train.shape[0]} baris')
print(f'Jumlah x_test : {x_test.shape[0]} baris')
print(f'Jumlah y_train : {y_train.shape[0]} baris')
print(f'Jumlah y_test : {y_test.shape[0]} baris')
# Out:
# Jumlah x_train : 159 baris
# Jumlah x_test : 39 baris
# Jumlah y_train : 159 baris
# Jumlah y_test : 39 baris

# %%
def min_max_scaler(train, test):
    min_val = np.min(train, axis=0)
    max_val = np.max(train, axis=0)
    epsilon = 1e-10
    train_scaled = (train - min_val) / (max_val - min_val + epsilon)
    test_scaled = (test - min_val) / (max_val - min_val + epsilon)
    
    return train_scaled, test_scaled

x_train_scaled, x_test_scaled = min_max_scaler(x_train, x_test)

# %%
def euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b) ** 2))

def manhattan_distance(a, b):
    return np.sum(np.abs(a - b))

def minkowski_distance(a, b, p):
    return np.sum(np.abs(a - b) ** p) ** (1 / p)

class KNeighborsClassifierManual:
    def __init__(self, n_neighbors=5, metric='euclidean', p=3):
        self.n_neighbors = n_neighbors
        self.metric = metric
        self.p = p

    def fit(self, X, y):
        self.X_train = X
        self.y_train = y

    def predict(self, X):
        predictions = [self._predict(x) for x in X]
        return np.array(predictions)
    
    def _predict(self, x):
        distances = [self._distance(x, x_train) for x_train in self.X_train]
        k_indices = np.argsort(distances)[:self.n_neighbors]
        k_nearest_labels = [self.y_train[i] for i in k_indices]
        most_common = np.bincount(k_nearest_labels).argmax()
        return most_common
    
    def _distance(self, a, b):
        if self.metric == 'euclidean':
            return euclidean_distance(a, b)
        elif self.metric == 'manhattan':
            return manhattan_distance(a, b)
        elif self.metric == 'minkowski':
            return minkowski_distance(a, b, self.p)
        else:
            raise ValueError(f"Unknown metric: {self.metric}")

# %%
def cross_val_score_knn(knn, X, y, cv=5):
    np.random.seed(42)
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)
    fold_sizes = np.full(cv, X.shape[0] // cv, dtype=int)
    fold_sizes[:X.shape[0] % cv] += 1
    current = 0
    scores = []

    for fold_size in fold_sizes:
        start, stop = current, current + fold_size
        test_indices = indices[start:stop]
        train_indices = np.concatenate([indices[:start], indices[stop:]])
        current = stop

        X_train, X_test = X[train_indices], X[test_indices]
        y_train, y_test = y[train_indices], y[test_indices]

        knn.fit(X_train, y_train)
        y_pred = knn.predict(X_test)
        accuracy = np.sum(y_pred == y_test) / len(y_test)
        scores.append(accuracy)

    return np.array(scores)

# %%
def grid_search_knn(X_train, y_train, param_grid, cv=5):
    best_score = 0
    best_params = None
    for n_neighbors in param_grid['n_neighbors']:
        for metric in param_grid['metric']:
            for p in param_grid.get('p', [3]):
                knn = KNeighborsClassifierManual(n_neighbors=n_neighbors, metric=metric, p=p)
                scores = cross_val_score_knn(knn, X_train, y_train, cv=cv)
                mean_score = scores.mean()
                if mean_score > best_score:
                    best_score = mean_score
                    best_params = {'n_neighbors': n_neighbors, 'metric': metric, 'p': p}
    return best_params, best_score

param_grid = {
    'n_neighbors': [3, 5, 7],
    'metric': ['euclidean', 'manhattan', 'minkowski'],
    'p': [1, 2, 3] 
}

best_params, best_score = grid_search_knn(x_train_scaled, y_train, param_grid, cv=10)
print(f'Best parameters: {best_params}')
print(f'Best cross-validation score: {best_score}')
# Out:
# Best parameters: {'n_neighbors': 5, 'metric': 'manhattan', 'p': 1}
# Best cross-validation score: 0.9058333333333334

# %%
knn = KNeighborsClassifierManual(**best_params)
knn.fit(x_train_scaled, y_train)
pred = knn.predict(x_test_scaled)

# %%
accuracy = np.mean(pred == y_test)
print(f'Akurasi Model KNN {accuracy}')
# Out:
# Akurasi Model KNN 0.9230769230769231

# %%
scores = cross_val_score_knn(knn, x_train_scaled, y_train, cv=10)
print(f'Cross-validation scores: {scores}')
print(f'Mean accuracy: {scores.mean()}')
# Out:
# Cross-validation scores: [0.9375     0.875      0.9375     0.875      0.8125     0.875
#  1.         1.         0.8125     0.93333333]
# Mean accuracy: 0.9058333333333334

# %%
def precision_recall_f1_support(y_true, y_pred, average=None):
    labels = np.unique(np.concatenate((y_true, y_pred)))
    report = {}
    
    for label in labels:
        tp = sum((y_true[i] == label) and (y_pred[i] == label) for i in range(len(y_true)))
        fp = sum((y_true[i] != label) and (y_pred[i] == label) for i in range(len(y_true)))
        fn = sum((y_true[i] == label) and (y_pred[i] != label) for i in range(len(y_true)))
        tn = sum((y_true[i] != label) and (y_pred[i] != label) for i in range(len(y_true)))

        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        support = sum(y == label for y in y_true)

        report[label] = {
            'precision': precision,
            'recall': recall,
            'f1-score': f1_score,
            'support': support
        }

    if average == 'macro':
        avg_precision = sum(report[label]['precision'] for label in labels) / len(labels)
        avg_recall = sum(report[label]['recall'] for label in labels) / len(labels)
        avg_f1_score = sum(report[label]['f1-score'] for label in labels) / len(labels)
        avg_support = sum(report[label]['support'] for label in labels)
        
        report['macro avg'] = {
            'precision': avg_precision,
            'recall': avg_recall,
            'f1-score': avg_f1_score,
            'support': avg_support
        }
    
    return report

def print_classification_report(report):
    print(f"{'Label':<10} {'Precision':<10} {'Recall':<10} {'F1-Score':<10} {'Support':<10}")
    print("="*50)
    for label, metrics in report.items():
        print(f"{label:<10} {metrics['precision']:<10.2f} {metrics['recall']:<10.2f} {metrics['f1-score']:<10.2f} {metrics['support']:<10}")

report_knn = precision_recall_f1_support(y_test, pred, average='macro')
print_classification_report(report_knn)
# Out:
# Label      Precision  Recall     F1-Score   Support
# ...
# 0          0.90       0.95       0.93       20
# 1          0.94       0.89       0.92       19
# macro avg  0.92       0.92       0.92       39

# %%
def confusion_matrix(y_test, y_pred):
    tp = fp = tn = fn = 0
    for true, pred in zip(y_test, y_pred):
        if true == 1 and pred == 1:
            tp += 1
        elif true == 0 and pred == 1:
            fp += 1
        elif true == 0 and pred == 0:
            tn += 1
        elif true == 1 and pred == 0:
            fn += 1
    
    confusion_matrix = np.array([[tn, fp], [fn, tp]])

    fig, ax = plt.subplots()
    ax.matshow(confusion_matrix, cmap='coolwarm', alpha=0.6)
    for i in range(confusion_matrix.shape[0]):
        for j in range(confusion_matrix.shape[1]):
            ax.text(x=j, y=i, s=confusion_matrix[i, j], va='center', ha='center')

    plt.xlabel('Prediksi')
    plt.ylabel('Aktual')
    plt.title('Confusion Matrix')
    plt.xticks([0, 1], ['Murah', 'Mahal'])
    plt.yticks([0, 1], ['Murah', 'Mahal'])
    plt.show()

confusion_matrix(y_test, pred)

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x, y, test_size=0.4, stratify=y, random_state=42)
print(f'Jumlah x_train alternatif : {x_train1.shape[0]} baris')
print(f'Jumlah x_test alternatif : {x_test1.shape[0]} baris')
print(f'Jumlah y_train alternatif : {y_train1.shape[0]} baris')
print(f'Jumlah y_test alternatif : {y_test1.shape[0]} baris')
# Out:
# Jumlah x_train alternatif : 120 baris
# Jumlah x_test alternatif : 78 baris
# Jumlah y_train alternatif : 120 baris
# Jumlah y_test alternatif : 78 baris

# %%
x_train_scaled1, x_test_scaled1 = min_max_scaler(x_train1, x_test1)

# %%
best_params, best_score = grid_search_knn(x_train_scaled1, y_train1, param_grid, cv=10)
print(f'Best parameters: {best_params}')
print(f'Best cross-validation score: {best_score}')
# Out:
# Best parameters: {'n_neighbors': 5, 'metric': 'euclidean', 'p': 1}
# Best cross-validation score: 0.9333333333333332

# %%
knn1 = KNeighborsClassifierManual(**best_params)
knn1.fit(x_train_scaled1, y_train1)
pred1 = knn1.predict(x_test_scaled1)

# %%
accuracy1 = np.mean(pred1 == y_test1)
print(f'Akurasi Model KNN {accuracy1}')
# Out:
# Akurasi Model KNN 0.8974358974358975

# %%
scores = cross_val_score_knn(knn, x_train_scaled1, y_train1, cv=10)
print(f'Cross-validation scores: {scores}')
print(f'Mean accuracy: {scores.mean()}')
# Out:
# Cross-validation scores: [1.         0.83333333 0.91666667 1.         0.91666667 1.
#  1.         0.75       0.91666667 1.        ]
# Mean accuracy: 0.9333333333333332

# %%
report_knn1 = precision_recall_f1_support(y_test1, pred1, average='macro')
print_classification_report(report_knn1)
# Out:
# Label      Precision  Recall     F1-Score   Support
# ...
# 0          0.85       0.97       0.91       40
# 1          0.97       0.82       0.89       38
# macro avg  0.91       0.90       0.90       78

# %%
confusion_matrix(y_test1, pred1)
