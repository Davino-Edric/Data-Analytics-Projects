# %% [markdown]
# # Car Price Dataset

# %% [markdown]
# Nama: Davino Edric & M. Shofian Najib
#
# Sekolah: SMKN 1 Surabaya

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('CarPrice_Assignment.csv')
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
dfc = df.copy(deep=True)
dfc.drop(columns='car_ID',inplace=True)

# %%
dfc.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in dfc.select_dtypes('number'):
    sns.boxenplot(dfc[col])
    plt.show()

# %%
# for col in dfc.select_dtypes('number'):
#     q1 = dfc[col].quantile(0.25)
#     q3 = dfc[col].quantile(0.75)
#     iqr = q3 - q1 
#     lwr = q1 - 1.5 * iqr
#     upr = q3 + 1.5 * iqr
    
#     dfc.loc[(dfc[col] < lwr) | (dfc[col] > upr),col] = dfc[col].mean().astype(dfc[col].dtype)

# %%
for col in dfc.select_dtypes('number'):
    sns.boxenplot(dfc[col])
    plt.show()

# %%
dfc['brand'] = dfc['CarName'].str.extract(r'^(\S+)\s')
dfc.drop(columns='CarName',inplace=True)
dfc['brand'].value_counts()
# Out:
# brand
# toyota         31
# nissan         17
# mazda          15
# honda          13
# mitsubishi     13
# peugeot        11
# volvo          11
# subaru         10
# dodge           9
# volkswagen      9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# porsche         4
# isuzu           4
# alfa-romero     3
# jaguar          3
# chevrolet       3
# renault         2
# maxda           2
# vw              2
# mercury         1
# porcshce        1
# Nissan          1
# toyouta         1
# vokswagen       1
# Name: count, dtype: int64

# %%
map_brand = {
    'maxda': 'mazda',
    'vw': 'volkswagen',
    'porcshce': 'porsche',
    'Nissan': 'nissan',
    'toyouta': 'toyota',
    'vokswagen': 'volkswagen',
    'alfa-romero': 'alfa-romeo',
}

dfc['brand'] = dfc['brand'].replace(map_brand)

dfc['brand'].value_counts()
# Out:
# brand
# toyota        32
# nissan        18
# mazda         17
# mitsubishi    13
# honda         13
# volkswagen    12
# peugeot       11
# volvo         11
# subaru        10
# dodge          9
# buick          8
# bmw            8
# audi           7
# plymouth       7
# saab           6
# porsche        5
# isuzu          4
# alfa-romeo     3
# chevrolet      3
# jaguar         3
# renault        2
# mercury        1
# Name: count, dtype: int64

# %%
dfc.isna().sum()
# Out:
# symboling           0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# brand               2
# dtype: int64

# %%
dfc[dfc['brand'].isna()]
# Out:
#      symboling fueltype aspiration doornumber    carbody drivewheel  \
# 138          2      gas        std        two  hatchback        fwd
# 141          0      gas        std       four      sedan        fwd
#
#     enginelocation  wheelbase  carlength  carwidth  ...  fuelsystem  \
# 138          front       93.7      156.9      63.4  ...        2bbl
# 141          front       97.2      172.0      65.4  ...        2bbl
#
#      boreratio stroke compressionratio  horsepower peakrpm  citympg  \
# 138       3.62   2.36              9.0          69    4900       31
# 141       3.62   2.64              9.5          82    4800       32
#
#      highwaympg   price  brand
# 138          36  5118.0    NaN
# 141          37  7126.0    NaN
#
# [2 rows x 25 columns]

# %%
dfc.shape
# Out:
# (205, 25)

# %%
dfc.loc[138, 'brand'] = 'saab'
dfc.loc[141, 'brand'] = 'subaru'

# %%
dfc.isna().sum()
# Out:
# symboling           0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# brand               0
# dtype: int64

# %%
for col in dfc.columns:
    sns.displot(dfc[col],kde=True)
    plt.show()

# %%
dfc.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# ...

# %%
dfc['brand'].value_counts()
# Out:
# brand
# toyota        32
# nissan        18
# mazda         17
# mitsubishi    13
# honda         13
# volkswagen    12
# subaru        11
# volvo         11
# peugeot       11
# dodge          9
# buick          8
# bmw            8
# audi           7
# saab           7
# plymouth       7
# porsche        5
# isuzu          4
# alfa-romeo     3
# chevrolet      3
# jaguar         3
# renault        2
# mercury        1
# Name: count, dtype: int64

# %%
dfc['price_group'] = pd.cut(df['price'], bins=[0,7788,10295,14399,(dfc['price'].max() + 1)], labels=[0,1,2,3])
dfc['car_size'] = dfc['carheight'] * dfc['carlength'] * dfc['carwidth']

# %%
dfc.isna().sum()
# Out:
# symboling           0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# brand               0
# price_group         0
# car_size            0
# dtype: int64

# %%
dfc[dfc['price_group'].isna()]
# Out:
# Empty DataFrame
# Columns: [symboling, fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price, brand, price_group, car_size]
# Index: []
#
# [0 rows x 27 columns]

# %%
dfc.select_dtypes('object')
# Out:
#     fueltype aspiration doornumber      carbody drivewheel enginelocation  \
# 0        gas        std        two  convertible        rwd          front
# 1        gas        std        two  convertible        rwd          front
# 2        gas        std        two    hatchback        rwd          front
# 3        gas        std       four        sedan        fwd          front
# 4        gas        std       four        sedan        4wd          front
# ..       ...        ...        ...          ...        ...            ...
# 200      gas        std       four        sedan        rwd          front
# 201      gas      turbo       four        sedan        rwd          front
# 202      gas        std       four        sedan        rwd          front
# 203   diesel      turbo       four        sedan        rwd          front
# 204      gas      turbo       four        sedan        rwd          front
#
#     enginetype cylindernumber fuelsystem       brand
# ...

# %%
for col in dfc.select_dtypes('object'):
    sns.countplot(x=dfc[col], hue=dfc['price_group'])
    plt.legend(['Murah','Sedang','Mahal','Luxury'])
    plt.show()

# %%
for col in dfc.select_dtypes('object'):
    if col != 'brand':
        plt.figure(figsize=(12,6))
        sns.boxenplot(x=dfc[col], y=dfc['price'])
        plt.show()
    else:
        plt.figure(figsize=(15,8))
        sns.boxenplot(y=dfc['brand'],x=dfc['price'])
        plt.show()
# Out:
#   Cell In[788], line 9
#     plt.show()
#     ^
# IndentationError: unexpected indent

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   fueltype          205 non-null    int64
#  2   aspiration        205 non-null    int64
#  3   doornumber        205 non-null    int64
#  4   carbody           205 non-null    int64
#  5   drivewheel        205 non-null    int64
#  6   enginelocation    205 non-null    int64
#  7   wheelbase         205 non-null    float64
#  8   carlength         205 non-null    float64
#  9   carwidth          205 non-null    float64
#  10  carheight         205 non-null    float64
#  11  curbweight        205 non-null    int64
#  12  enginetype        205 non-null    int64
#  13  cylindernumber    205 non-null    int64
#  14  enginesize        205 non-null    int64
#  15  fuelsystem        205 non-null    int64
# ...

# %%
for col in dfc[['cylindernumber','horsepower','enginelocation','doornumber','boreratio','enginesize','drivewheel']]:
        plt.figure(figsize=(15,8))
        sns.boxenplot(y=dfc['brand'],x=dfc[col])
        plt.show()

# %%
expy = dfc.groupby('brand')['price'].median()

# %%
expy
# Out:
# brand
# alfa-romeo    16500.0
# audi          17710.0
# bmw           22835.0
# buick         32892.0
# chevrolet      6295.0
# dodge          7609.0
# honda          7295.0
# isuzu          8916.5
# jaguar        35550.0
# mazda         10595.0
# mercury       16503.0
# mitsubishi     8499.0
# nissan         8124.0
# peugeot       16630.0
# plymouth       7609.0
# porsche       32528.0
# renault        9595.0
# saab          15040.0
# subaru         8013.0
# toyota         9103.0
# volkswagen     9737.5
# volvo         18420.0
# Name: price, dtype: float64

# %%
dfc['brand_group'] = dfc['brand'].apply(lambda x: 0 if expy[x] < 10000 else (1 if (expy[x] < 20000) and (expy[x]> 10000) else 2))

# %%
plt.figure(figsize=(12,10))
sns.barplot(x=dfc['brand_group'],y=dfc['price'], hue=dfc['price_group'])
plt.legend(['Murah','Sedang','Mahal','Luxury'])
plt.show()

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   fueltype          205 non-null    object
#  2   aspiration        205 non-null    object
#  3   doornumber        205 non-null    object
#  4   carbody           205 non-null    object
#  5   drivewheel        205 non-null    object
#  6   enginelocation    205 non-null    object
#  7   wheelbase         205 non-null    float64
#  8   carlength         205 non-null    float64
#  9   carwidth          205 non-null    float64
#  10  carheight         205 non-null    float64
#  11  curbweight        205 non-null    int64
#  12  enginetype        205 non-null    object
#  13  cylindernumber    205 non-null    object
#  14  enginesize        205 non-null    int64
#  15  fuelsystem        205 non-null    object
# ...

# %%
for col in dfc[['cylindernumber','horsepower','enginelocation','doornumber','boreratio','enginesize','drivewheel']]:
        plt.figure(figsize=(15,8))
        sns.boxenplot(y=dfc['brand'],x=dfc[col])
        plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(y=dfc['brand'], order=dfc['brand'].value_counts().index ,hue=dfc['brand'])
plt.show()

# %%
dicto = {}
for col in dfc[['fueltype','aspiration','doornumber','enginelocation','cylindernumber','brand','carbody','drivewheel','fuelsystem','enginetype']]:
    dfc[col], dicto[col] = pd.factorize(dfc[col])
    
dfc.select_dtypes('object').head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
# dfc= pd.get_dummies(data=dfc, columns=['carbody','drivewheel','fuelsystem','enginetype'],drop_first=True).astype(int)

# %%
dfc.head()
# Out:
#    symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0          3         0           0           0        0           0
# 1          3         0           0           0        0           0
# 2          1         0           0           0        1           0
# 3          2         0           0           1        2           1
# 4          2         0           0           1        2           2
#
#    enginelocation  wheelbase  carlength  carwidth  ...  compressionratio  \
# 0               0       88.6      168.8      64.1  ...               9.0
# 1               0       88.6      168.8      64.1  ...               9.0
# 2               0       94.5      171.2      65.5  ...               9.0
# 3               0       99.8      176.6      66.2  ...              10.0
# 4               0       99.4      176.6      66.4  ...               8.0
#
#    horsepower  peakrpm  citympg  highwaympg    price  brand  price_group  \
# ...

# %%
dicto['brand']
# Out:
# Index(['alfa-romeo', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda', 'isuzu',
#        'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi', 'nissan',
#        'peugeot', 'plymouth', 'porsche', 'renault', 'saab', 'subaru', 'toyota',
#        'volkswagen', 'volvo'],
#       dtype='object')

# %%
plt.figure(figsize=(20,12))
sns.heatmap(dfc.corr(),annot=True,cmap='coolwarm')
plt.show()
plt.figure(figsize=(20,12))
sns.heatmap(dfc.corr('spearman'),annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# Brainstorm:
# 1. Mobil yang lebih gede bakalan lebih mahal
# 2. Brand itu menentukan harga mobil (brand_group)
# 3. Karakteristik mobil mahal antara lain: Piston lebih banyak, Horsepower lebih gede, mesinnya di belakang atau di depan, doornumber
