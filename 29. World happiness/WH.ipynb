# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('2019.csv')
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
df_num = df.select_dtypes('float64')
df_num.head()
# Out:
#    Score  GDP per capita  Social support  Healthy life expectancy  \
# 0  7.769           1.340           1.587                    0.986
# 1  7.600           1.383           1.573                    0.996
# 2  7.554           1.488           1.582                    1.028
# 3  7.494           1.380           1.624                    1.026
# 4  7.488           1.396           1.522                    0.999
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.596       0.153                      0.393
# 1                         0.592       0.252                      0.410
# 2                         0.603       0.271                      0.341
# 3                         0.591       0.354                      0.118
# 4                         0.557       0.322                      0.298

# %% [markdown]
# # Soal 1

# %% [markdown]
# ## Mean, Median, Modus

# %%
df_num.mean()
# Out:
# Score                           5.407096
# GDP per capita                  0.905147
# Social support                  1.208814
# Healthy life expectancy         0.725244
# Freedom to make life choices    0.392571
# Generosity                      0.184846
# Perceptions of corruption       0.110603
# dtype: float64

# %%
df_num.median()
# Out:
# Score                           5.3795
# GDP per capita                  0.9600
# Social support                  1.2715
# Healthy life expectancy         0.7890
# Freedom to make life choices    0.4170
# Generosity                      0.1775
# Perceptions of corruption       0.0855
# dtype: float64

# %%
df_num.mode()
# Out:
#    Score  GDP per capita  Social support  Healthy life expectancy  \
# 0  5.208            0.96           1.465                    0.815
# 1    NaN             NaN             NaN                    0.999
# 2    NaN             NaN             NaN                      NaN
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.498       0.153                      0.028
# 1                         0.508         NaN                      0.078
# 2                         0.557         NaN                      0.089

# %% [markdown]
# ## Range, Q1, Q2, & IQR

# %%
range_num = (df_num.max() - df_num.min())
range_num
# Out:
# Score                           4.916
# GDP per capita                  1.684
# Social support                  1.624
# Healthy life expectancy         1.141
# Freedom to make life choices    0.631
# Generosity                      0.566
# Perceptions of corruption       0.453
# dtype: float64

# %%
q1 = df_num.quantile(0.25)
q3 = df_num.quantile(0.75)
iqr = q3-q1
print(q1)
print(q3)
print(iqr)
# Out:
# Score                           4.54450
# GDP per capita                  0.60275
# Social support                  1.05575
# Healthy life expectancy         0.54775
# Freedom to make life choices    0.30800
# Generosity                      0.10875
# Perceptions of corruption       0.04700
# Name: 0.25, dtype: float64
# Score                           6.18450
# GDP per capita                  1.23250
# Social support                  1.45250
# Healthy life expectancy         0.88175
# Freedom to make life choices    0.50725
# Generosity                      0.24825
# Perceptions of corruption       0.14125
# Name: 0.75, dtype: float64
# Score                           1.64000
# GDP per capita                  0.62975
# Social support                  0.39675
# Healthy life expectancy         0.33400
# Freedom to make life choices    0.19925
# Generosity                      0.13950
# Perceptions of corruption       0.09425
# dtype: float64

# %% [markdown]
# ## Standard Deviation & Variance

# %%
df_num.var()
# Out:
# Score                           1.239036
# GDP per capita                  0.158714
# Social support                  0.089515
# Healthy life expectancy         0.058624
# Freedom to make life choices    0.020532
# Generosity                      0.009073
# Perceptions of corruption       0.008937
# dtype: float64

# %%
df_num.std()
# Out:
# Score                           1.113120
# GDP per capita                  0.398389
# Social support                  0.299191
# Healthy life expectancy         0.242124
# Freedom to make life choices    0.143289
# Generosity                      0.095254
# Perceptions of corruption       0.094538
# dtype: float64

# %% [markdown]
# ## Z score

# %%
zs = (df_num - df_num.mean()) / df_num.std()

# %%
zs
# Out:
#         Score  GDP per capita  Social support  Healthy life expectancy  \
# 0    2.121877        1.091526        1.264027                 1.076954
# 1    1.970052        1.199461        1.217234                 1.118255
# 2    1.928727        1.463022        1.247315                 1.250419
# 3    1.874824        1.191931        1.387693                 1.242159
# 4    1.869434        1.232092        1.046774                 1.130646
# ..        ...             ...             ...                      ...
# 151 -1.862420       -1.370888       -1.663865                -0.459449
# 152 -1.954952       -1.077206       -1.082297                -0.934412
# 153 -1.980107       -1.393479       -2.312279                -1.504368
# 154 -2.087912       -2.206754       -4.040270                -2.561677
# 155 -2.294538       -1.503924       -2.118424                -1.776956
#
#      Freedom to make life choices  Generosity  Perceptions of corruption
# ...

# %% [markdown]
# # Soal 2

# %% [markdown]
# ## IQR & Z Score

# %%
odf_iqr = {}
for col in df_num.columns:
    q1 = df_num[col].quantile(0.25)
    q3 = df_num[col].quantile(0.75)
    iqr = q3 - q1 
    upr = q3 + 1.5 * iqr
    lwr = q1 - 1.5 * iqr
    
    zs = (df_num[col] - df_num[col].mean()) / df_num[col].std()
    
    odf_iqr = df_num.loc[(df_num[col] < lwr) | (df_num[col] > upr)]
    odf_zs = df_num[np.abs(zs) > 3]

# %% [markdown]
# ## IQR

# %%
odf_iqr
# Out:
#      Score  GDP per capita  Social support  Healthy life expectancy  \
# 0    7.769           1.340           1.587                    0.986
# 1    7.600           1.383           1.573                    0.996
# 2    7.554           1.488           1.582                    1.028
# 4    7.488           1.396           1.522                    0.999
# 5    7.480           1.452           1.526                    1.052
# 6    7.343           1.387           1.487                    1.009
# 7    7.307           1.303           1.557                    1.026
# 8    7.278           1.365           1.505                    1.039
# 10   7.228           1.372           1.548                    1.036
# 13   7.090           1.609           1.479                    1.012
# 15   7.021           1.499           1.553                    0.999
# 33   6.262           1.572           1.463                    1.141
# 75   5.430           1.438           1.277                    1.122
# ...

# %% [markdown]
# ## Z score

# %%
odf_zs
# Out:
#      Score  GDP per capita  Social support  Healthy life expectancy  \
# 1    7.600           1.383           1.573                    0.996
# 33   6.262           1.572           1.463                    1.141
# 151  3.334           0.359           0.711                    0.614
#
#      Freedom to make life choices  Generosity  Perceptions of corruption
# 1                           0.592       0.252                      0.410
# 33                          0.556       0.271                      0.453
# 151                         0.555       0.217                      0.411

# %% [markdown]
# # Soal 3

# %%
for col in df_num.columns:
    sns.boxplot(df[col])
    plt.show()
    sns.histplot(df[col])
    plt.show()

# %% [markdown]
# # Soal 4

# %% [markdown]
# ## Covariance correlation

# %%
cov_dict = {}
for col in df_num.columns:
    cov_dict[col] = np.cov(df_num[col],df_num['Score'], bias=True)[0][1]
    
cov_dict
# Out:
# {'Score': np.float64(1.2310933048570023),
#  'GDP per capita': np.float64(0.3497947678747534),
#  'Social support': np.float64(0.2571292358234713),
#  'Healthy life expectancy': np.float64(0.2088413099112426),
#  'Freedom to make life choices': np.float64(0.08981493873274159),
#  'Generosity': np.float64(0.00798802120315582),
#  'Perceptions of corruption': np.float64(0.04031869206114396)}

# %% [markdown]
# ## Pearson Correlation (Hubungan Linear)

# %%
sns.heatmap(df_num.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ## Spearman (Hubungan Non Linear)

# %%
sns.heatmap(df_num.corr('spearman'), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ## Kendall Tau (Ordinal Correlation)

# %%
sns.heatmap(df_num.corr('kendall'), annot=True, cmap='coolwarm')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
dfs_gdp = df.sort_values(by='GDP per capita', ascending=False)
gdp10 = dfs_gdp.head(10)
gdp10

sns.barplot(x=gdp10['GDP per capita'],y=gdp10['Country or region'])
plt.show()

# %%
dfs_hle = df.sort_values(by='Healthy life expectancy', ascending=False)
hle10 = dfs_hle.head(10)
hle10

sns.barplot(x=hle10['Healthy life expectancy'],y=hle10['Country or region'])
plt.show()

# %%
dfs_pc = df.sort_values(by='Perceptions of corruption', ascending=False)
pc10 = dfs_pc.head(10)
pc10

sns.barplot(x=pc10['Perceptions of corruption'],y=pc10['Country or region'])
plt.show()
