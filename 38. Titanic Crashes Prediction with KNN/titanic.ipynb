# %% [markdown]
# ## Import & EDA (Exploratory Data Analysis)

# %% [markdown]
# Sekolah: SMKN 1 Surabaya
#
# Peserta: Davino Edric & M. Shofian Najib
#
# Tanggal: 26 Maret 2025

# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Penjelasan kolom:
# - PassengerID
# - Survived (0,1)
# - PClass
# - Name
# - Sex
# - Age
# - Ticket nomor tiket yang akan dinaiki
# - Fare(Harga)
# - Cabin
# - Parch (Jumlah orang tua / anak di kapal)
# - Sibsp (Jumlah saudara di kapal)
# - Embarked (Tempat kapal berlabuh)

# %%
df = pd.read_csv('train.csv')
df.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %% [markdown]
# ## Soal 1.1 Bar plot Sex

# %%
df.groupby(['Sex']).size().plot(kind='bar',stacked=True,color=['red','yellow'])
plt.title('Distribusi gender')
plt.show()

# %% [markdown]
# ## Soal 1.2: KDE plot & statistical summary

# %% [markdown]
# ### KDE plot

# %%
sns.kdeplot(x=df['Age'],y=df['Survived'])
plt.show()

# %% [markdown]
# ### Membuat dataframe copy serta dataframe yang dibagi berdasarkan survive

# %%
dfs = df[df['Survived']== 1]
dfns = df[df['Survived']== 0]
dfc = df.copy(deep=True)

# %% [markdown]
# ###  Mengecek Mean, Median tiap class survive

# %%
dfs.describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   342.000000     342.0  342.000000  290.000000  342.000000  342.000000
# mean    444.368421       1.0    1.950292   28.343690    0.473684    0.464912
# std     252.358840       0.0    0.863321   14.950952    0.708688    0.771712
# min       2.000000       1.0    1.000000    0.420000    0.000000    0.000000
# 25%     250.750000       1.0    1.000000   19.000000    0.000000    0.000000
# 50%     439.500000       1.0    2.000000   28.000000    0.000000    0.000000
# 75%     651.500000       1.0    3.000000   36.000000    1.000000    1.000000
# max     890.000000       1.0    3.000000   80.000000    4.000000    5.000000
#
#              Fare
# count  342.000000
# mean    48.395408
# std     66.596998
# min      0.000000
# 25%     12.475000
# 50%     26.000000
# 75%     57.000000
# max    512.329200

# %%
dfns.describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   549.000000     549.0  549.000000  424.000000  549.000000  549.000000
# mean    447.016393       0.0    2.531876   30.626179    0.553734    0.329690
# std     260.640469       0.0    0.735805   14.172110    1.288399    0.823166
# min       1.000000       0.0    1.000000    1.000000    0.000000    0.000000
# 25%     211.000000       0.0    2.000000   21.000000    0.000000    0.000000
# 50%     455.000000       0.0    3.000000   28.000000    0.000000    0.000000
# 75%     675.000000       0.0    3.000000   39.000000    1.000000    0.000000
# max     891.000000       0.0    3.000000   74.000000    8.000000    6.000000
#
#              Fare
# count  549.000000
# mean    22.117887
# std     31.388207
# min      0.000000
# 25%      7.854200
# 50%     10.500000
# 75%     26.000000
# max    263.000000

# %% [markdown]
# ### Mengecek Distribusi umur untuk setiap kelompok survive

# %%
sns.displot(dfs['Age'],kde=True)
plt.show()

# %%
sns.displot(dfns['Age'],kde=True)
plt.show()

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# ## Soal 1.3 Korelasi Fare,Pclass dengan Survived

# %%
df[['Pclass','Fare','Survived']].corr()
# Out:
#             Pclass      Fare  Survived
# Pclass    1.000000 -0.549500 -0.338481
# Fare     -0.549500  1.000000  0.257307
# Survived -0.338481  0.257307  1.000000

# %% [markdown]
# ## Soal 1.4 Distribusi Fare dengan kelas (Pclass dan Survived)

# %%
sns.boxplot(x=df['Pclass'],y=df['Fare'])
plt.show()

# %%
sns.boxplot(x=df['Survived'],y=df['Fare'])
plt.show()

# %% [markdown]
# ### insights: Harga bervariasi berdasarkan penjual dari tiket titanic (Official, reseller, dst)

# %% [markdown]
# ## Soal 1.5: Korelasi Pearson

# %%
df[['Pclass','Fare','Survived']].corr('pearson')
# Out:
#             Pclass      Fare  Survived
# Pclass    1.000000 -0.549500 -0.338481
# Fare     -0.549500  1.000000  0.257307
# Survived -0.338481  0.257307  1.000000

# %% [markdown]
# ### Mengecek Distribusi kolom Numerik

# %%
for col in df.select_dtypes('number'):
    sns.displot(df[col])
    plt.show()

# %% [markdown]
# ## Soal 1.6: Korelasi FamilySize dengan Survived (Sekaligus menyelesaikan Soal 2.4)

# %%
dfc['FamilySize'] = dfc['Parch'] + dfc['SibSp'] + 1
dfc.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Miss. John Bradley (Florence Briggs T...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3      Futrelle, Miss. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      0         A/5 21171   7.2500   NaN        S           2
# 1      0          PC 17599  71.2833   C85        C           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1
# ...

# %%
dfc[['Survived','FamilySize']].corr('pearson')
# Out:
#             Survived  FamilySize
# Survived    1.000000    0.016639
# FamilySize  0.016639    1.000000

# %%
sns.boxplot(dfc['FamilySize'])
plt.show()

# %% [markdown]
# ## Soal 1.7: Outlier IQR dan Z Scores

# %%
ozs = {}
oiqr = {}
for col in dfc[['Fare','Age']]:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3- q1
    lwr = q1 - 1.5 * iqr
    upr = q3 + 1.5 * iqr
    
    oiqr[col] = df.loc[(df[col] < lwr)|(df[col] > upr),col]
    
    zs = (df[col] - df[col].mean()) / df[col].std()
    ozs[col] = zs[abs(zs) > 3]

# %% [markdown]
# ### Outlier IQR

# %%
ozs
# Out:
# {'Fare': 27     4.644393
#  88     4.644393
#  118    4.332899
#  258    9.661740
#  299    4.332899
#  311    4.631815
#  341    4.644393
#  377    3.608038
#  380    3.930516
#  438    4.644393
#  527    3.814891
#  557    3.930516
#  679    9.661740
#  689    3.604768
#  700    3.930516
#  716    3.930516
#  730    3.604768
#  737    9.661740
#  742    4.631815
#  779    3.604768
#  Name: Fare, dtype: float64,
#  'Age': 630    3.462699
#  851    3.049660
#  Name: Age, dtype: float64}

# %% [markdown]
# ### Outlier Z Scores

# %%
oiqr
# Out:
# {'Fare': 1       71.2833
#  27     263.0000
#  31     146.5208
#  34      82.1708
#  52      76.7292
#           ...
#  846     69.5500
#  849     89.1042
#  856    164.8667
#  863     69.5500
#  879     83.1583
#  Name: Fare, Length: 116, dtype: float64,
#  'Age': 33     66.0
#  54     65.0
#  96     71.0
#  116    70.5
#  280    65.0
#  456    65.0
#  493    71.0
#  630    80.0
#  672    70.0
#  745    70.0
#  851    74.0
#  Name: Age, dtype: float64}

# %% [markdown]
# ### Penggantian Outlier dengan median menggunakan IQR method

# %%
for col in dfc[['Fare','Age']]:
    q1 = dfc[col].quantile(0.25)
    q3 = dfc[col].quantile(0.75)
    iqr = q3- q1
    lwr = q1 - 1.5 * iqr
    upr = q3 + 1.5 * iqr
    
    dfc.loc[(dfc[col] < lwr)|(dfc[col] > upr),col] = dfc[col].median()

# %% [markdown]
# ## Soal 1.8: Pengecekan Korelasi Menggunakan heatmap

# %%
dfc['Sex'] = dfc['Sex'].str.strip()

# %%
sex_mapping = {
    'female' : 0,'male' : 1
}
dfc['Sex'] = dfc['Sex'].map(sex_mapping)

# %%
dfc['Sex']
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 891, dtype: int64

# %%
sns.heatmap(dfc.select_dtypes('number').corr('pearson'),annot=True,cmap='coolwarm')
plt.show()
sns.heatmap(dfc.select_dtypes('number').corr('spearman'),annot=True,cmap='coolwarm')
plt.show()
sns.heatmap(dfc.select_dtypes('number').corr('kendall'),annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# # 2. Preprocessing

# %% [markdown]
# ### Mengecek Hint tentang Cabin yang eksklusif

# %%
cabin_check = df.copy()
cabin_check.dropna(inplace=True)

# %%
cabin_check['Cabin'].unique()
# Out:
# array(['C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6', 'C23 C25 C27',
#        'D33', 'B30', 'C83', 'F33', 'F G73', 'E31', 'A5', 'D10 D12', 'D26',
#        'C110', 'B58 B60', 'E101', 'D47', 'B86', 'F2', 'C2', 'B19', 'A7',
#        'C49', 'F4', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'B49',
#        'D', 'C22 C26', 'C65', 'E36', 'C54', 'B57 B59 B63 B66', 'C7',
#        'E34', 'C32', 'B18', 'C124', 'C91', 'E40', 'T', 'E33', 'D37',
#        'B35', 'E50', 'C82', 'B96 B98', 'E10', 'C52', 'E44', 'A34', 'C104',
#        'C111', 'C92', 'E38', 'E12', 'E63', 'B37', 'C30', 'D20', 'B79',
#        'E25', 'D46', 'B73', 'B38', 'B39', 'B22', 'C86', 'C70', 'A16',
#        'C101', 'C68', 'A10', 'E68', 'B41', 'A20', 'D19', 'D50', 'D9',
#        'A23', 'B50', 'A26', 'D48', 'E58', 'B71', 'B51 B53 B55', 'D49',
#        'B5', 'B20', 'F G63', 'C62 C64', 'E24', 'C90', 'C126', 'C45', 'E8',
# ...

# %% [markdown]
# ## Soal 2.1: Mengisi Nan

# %% [markdown]
# ### Membuat kolom HasCabin

# %%
dfc['Cabin'] = dfc['Cabin'].fillna(0)
dfc['HasCabin'] = dfc['Cabin'].apply(lambda x: 0 if x == 0 else 1) # ada == 1

# %% [markdown]
# ### Mengisi Embarked dengan modus

# %%
dfc['Embarked'] = dfc['Embarked'].fillna(dfc['Embarked'].mode()[0])

# %% [markdown]
# ### Mengisi Age dengan mencari umur modus di tiap Pclass

# %%
sns.heatmap(dfc[['Pclass','Age']].corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
filler = dfc.groupby('Pclass')['Age'].transform(lambda x: x.mode()[0])

# %%
filler
# Out:
# 0      22.0
# 1      28.0
# 2      22.0
# 3      28.0
# 4      22.0
#        ...
# 886    28.0
# 887    28.0
# 888    22.0
# 889    28.0
# 890    22.0
# Name: Age, Length: 891, dtype: float64

# %%
dfc['Age'] = dfc['Age'].fillna(filler)

# %% [markdown]
# ### Mengecek Pengisian Nan

# %%
dfc.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# FamilySize     0
# HasCabin       0
# dtype: int64

# %% [markdown]
# ## Soal 2.2: Mengambil Title dari Nama tiap penumpang

# %%
dfc['Title'] = dfc['Name'].str.extract(r',\s(.*?)\.')
dfc.drop(columns='Name',inplace=True)

# %%
dfc.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0            1         0       3    1  22.0      1      0         A/5 21171
# 1            2         1       1    0  38.0      1      0          PC 17599
# 2            3         1       3    0  26.0      0      0  STON/O2. 3101282
# 3            4         1       1    0  35.0      1      0            113803
# 4            5         0       3    1  35.0      0      0            373450
#
#       Fare Cabin Embarked  FamilySize  HasCabin Title
# 0   7.2500     0        S           2         0    Mr
# 1  14.4542   C85        C           2         1  Miss
# 2   7.9250     0        S           1         0  Miss
# 3  53.1000  C123        S           2         1  Miss
# 4   8.0500     0        S           1         0    Mr

# %% [markdown]
# ### Mengecek error ketika pengisian

# %%
dfc['Title'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Melihat distribusi title pada awalnya

# %%
dfc['Title'].value_counts()
# Out:
# Title
# Mr              527
# Miss            311
# Master           40
# Dr                7
# Major             2
# Lady              1
# Sir               1
# Capt              1
# the Countess      1
# Name: count, dtype: int64

# %% [markdown]
# - **Distribusi Original**
#
# - Title
# - Mr              517
# - Miss            182
# - Mrs             125
# - Master           40
# - Dr                7
# - Rev               6
# - Col               2
# - Mlle              2
# - Major             2
# - Ms                1
# - Mme               1
# - Don               1
# - Lady              1
# - Sir               1
# - Capt              1
# - the Countess      1
# - Jonkheer          1

# %% [markdown]
# - List nama yang terscan sebagai title:
# 1. Col
# 2. Jonkheer
# 3. Rev
#
# - List title dalam bahasa lain:
# 1. Don (Mr)
# 2. Mlee (Miss)
# 3. Mme (Miss)

# %% [markdown]
# ### Lalu kami melakukan manipulasi nama di csv secara langsung karena step ini spesifik untuk tiap kasus (nama)

# %%
dfc['Title'].value_counts()
# Out:
# Title
# Mr              527
# Miss            311
# Master           40
# Dr                7
# Major             2
# Lady              1
# Sir               1
# Capt              1
# the Countess      1
# Name: count, dtype: int64

# %% [markdown]
# ### Pengelompokan Age dan Fare untuk Visualisasi

# %%
dfc['Age_Group'] = pd.cut(dfc['Age'], bins=[0,18,25,45,65],labels=[0,1,2,3])
dfc['Fare_Group'] = pd.cut(dfc['Fare'], bins=[0,7,14,24,66],labels=[0,1,2,3])

# %%
for col in dfc[['Pclass','Age_Group','Fare_Group','FamilySize','HasCabin','Sex','Title','Embarked']]:
    plt.figure(figsize=(12,5))
    sns.countplot(data=dfc, x=col, hue='Survived')
    plt.legend(['Tidak selamat','Selamat'])
    plt.show()

# %%
dfc['Sex'].value_counts()
# Out:
# Sex
# 1    577
# 0    314
# Name: count, dtype: int64

# %%
dfc['Title'].value_counts()
# Out:
# Title
# Mr              527
# Miss            311
# Master           40
# Dr                7
# Major             2
# Lady              1
# Sir               1
# Capt              1
# the Countess      1
# Name: count, dtype: int64

# %%
df_title = dfc[dfc['Title'] != 'Mr']
df_title = df_title[df_title['Title'] != 'Miss']

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=dfc, x=df_title['Title'], hue='Survived')
plt.legend(['Tidak selamat','Selamat'])
plt.show()

# %%
sns.boxplot(dfc['FamilySize'])
plt.show()

# %%
dfc['FamilySize'] = dfc['FamilySize'].apply(lambda x: 5 if x > 5 else x)

# %%
sns.boxplot(dfc['FamilySize'])
plt.show()

# %% [markdown]
# Insight yang ditemukan:
# 1. **Penumpang dengan tiket class 1 dan 2 memiliki rasio selamat yang lebih tinggi dibanding penumpang dengan tiket class 3**. (Tim penyelamatan lebih mementingkan penumpang yang memiliki tiket bisnis class / first class).
#
# 2. **Hanya penumpang anak-anak (dibawah 18 tahun) yang memiliki rasio keselamatan positif (Lebih banyak hidup dibanding meninggal)**, ini **dikarenakan anak-anak akan lebih diprioritaskan dalam misi penyelamatan** dibanding orang yang lebih tua. Sementara itu, **penumpang remaja dan dewasa memiliki rasio kematian yang lebih tinggi dibanding lansia**, ini dikarenakan **remaja dan dewasa lebih menikmati kemegahan di Titanic** dibanding kelompok Lansia.
#
# 3. Kolom kelompok harga tiket (Rendah,sedang,mahal) memberi tahu bahwa **membayar lebih mahal tidak berarti akan selamat dari bahaya,** memang terlihat lebih banyak penumpang yang selamat dengan harga tiket yang lebih mahal, namun **perlu diingat bahwa ini berkorelasi dengan kolom tiket class.** Jadi, tidak ada hubungan langsung antara harga tiket dan kemungkinan selamat. **Jika ingin selamat, beli lah tiket business class atau first class, bukan beli tiket yang mahal.**
#
# 4. Dari kolom FamilySize, terlihat kalau **pasangan maupun keluarga beranak 2 memiliki rasio yang lebih tinggi dibanding penumpang tunggal atau keluarga besar**. Ini disebabkan karena **kepedulian antar pasangan maupun keluarga serta kecilnya jumlah anggota keluarga** yang lebih mudah untuk diselamatkan dibanding keluarga besar.
#
# 5. **Terlihat bahwa perempuan (0) lebih cenderung diselamatkan oleh tim penyelamatan dibanding laki-laki (1) meskipun lebih banyak penumpang laki-laki**, ini disebabkan oleh **perasaan empati terhadap perempuan dibanding laki-laki**, yang dimana perempuan **sering memiliki nilai yang lebih tinggi dalam kasus bertahan hidup.**
#
# 6. Terlihat dari visualisasi kolom Title pertama **bahwa orang yang memiliki title / jabatan memiliki rasio kematian yang berbeda-beda**, namun **title Master memiliki tingkat kematian yang lebih rendah dibanding title Mr** atau Miss. Di visualisasi kedua, kita dapat melihat bahwa **Sir, The Countess, dan Lady (Tiga title yang kami anggap tertinggi) semuanya selamat**, ini kemungkinan besar karena **mereka yang memberi dana / orang penting dalam projek kapal Titanik**. *(Selain itu dapat ditemukan bahwa kapten kapal tersebut meninggal)*
#
# 7. Kita dapat melihat dari visualisasi kolom Embarked bahwa **banyak kapal yang berangkat dari pelabuhan Southhampton, dan dia juga pelabuhan yang memiliki rasio kematian tertinggi** dibanding dua pelabuhan lain. Selain itu, kapal dari **pelabuhan Cherbourgh memiliki rasio keselamatan yang positif,** menunjukkan bahwa kapal titanic kemungkinan **tenggelam tidak jauh dari pelabuhan,** dan bahwa kapal dari **Cherbourgh memiliki kesiapan yang lebih baik ketika ada kondisi darurat.**

# %% [markdown]
# ## Melakukan penghapusan outlier pada kolom FamilySize untuk improve model

# %%
dfc.loc[(dfc['FamilySize'] < lwr)|(dfc['FamilySize'] > upr),'FamilySize'] = 5

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=dfc, x=dfc['FamilySize'], hue='Survived')
plt.legend(['Tidak selamat','Selamat'])
plt.show()

# %% [markdown]
# ## Soal 2.3: Melakukan One Hot Encoding terhadap kolom Sex, Embarked, dan Title

# %%
title = dfc['Title']
dfc = pd.get_dummies(dfc, columns=['Sex','Embarked','Title'], drop_first=True)

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PassengerId         891 non-null    int64
#  1   Survived            891 non-null    int64
#  2   Pclass              891 non-null    int64
#  3   Age                 891 non-null    float64
#  4   SibSp               891 non-null    int64
#  5   Parch               891 non-null    int64
#  6   Ticket              891 non-null    object
#  7   Fare                891 non-null    float64
#  8   Cabin               891 non-null    object
#  9   FamilySize          891 non-null    int64
#  10  HasCabin            891 non-null    int64
#  11  Age_Group           891 non-null    category
#  12  Fare_Group          876 non-null    category
#  13  Sex_1               891 non-null    bool
#  14  Embarked_Q          891 non-null    bool
# ...

# %%
dfc.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   27.930045    0.523008
# std     257.353842    0.486592    0.836071   12.452442    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   26.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   64.000000    8.000000
#
#             Parch        Fare  FamilySize    HasCabin
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.381594   17.383622    1.785634    0.228956
# std      0.806057   12.713016    1.195524    0.420397
# min      0.000000    0.000000    1.000000    0.000000
# 25%      0.000000    7.910400    1.000000    0.000000
# ...

# %%
dicto = {}
for col in dfc.select_dtypes('bool'):
    mapping = {label: idx for idx,label in enumerate(dfc[col].unique())}
    dicto[col] = mapping
    dfc[col] = dfc[col].map(mapping)

# %%
dfc.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch            Ticket  \
# 0            1         0       3  22.0      1      0         A/5 21171
# 1            2         1       1  38.0      1      0          PC 17599
# 2            3         1       3  26.0      0      0  STON/O2. 3101282
# 3            4         1       1  35.0      1      0            113803
# 4            5         0       3  35.0      0      0            373450
#
#       Fare Cabin  FamilySize  ...  Embarked_Q Embarked_S Title_Dr  Title_Lady  \
# 0   7.2500     0           2  ...           0          0        0           0
# 1  14.4542   C85           2  ...           0          1        0           0
# 2   7.9250     0           1  ...           0          0        0           0
# 3  53.1000  C123           2  ...           0          0        0           0
# 4   8.0500     0           1  ...           0          0        0           0
#
#    Title_Major  Title_Master  Title_Miss  Title_Mr  Title_Sir  \
# ...

# %% [markdown]
# ## Soal 2.5: Melakukan Konversi Tiket

# %%
dfc['Ticket'] = dfc.groupby('Ticket')['Ticket'].transform('count')

# %%
dfc.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch  Ticket     Fare Cabin  \
# 0            1         0       3  22.0      1      0       1   7.2500     0
# 1            2         1       1  38.0      1      0       1  14.4542   C85
# 2            3         1       3  26.0      0      0       1   7.9250     0
# 3            4         1       1  35.0      1      0       2  53.1000  C123
# 4            5         0       3  35.0      0      0       1   8.0500     0
#
#    FamilySize  ...  Embarked_Q Embarked_S Title_Dr  Title_Lady  Title_Major  \
# 0           2  ...           0          0        0           0            0
# 1           2  ...           0          1        0           0            0
# 2           1  ...           0          0        0           0            0
# 3           2  ...           0          0        0           0            0
# 4           1  ...           0          0        0           0            0
#
# ...

# %%
dfc['Cabin'].value_counts()
# Out:
# Cabin
# 0              687
# G6               4
# C23 C25 C27      4
# B96 B98          4
# F2               3
#               ...
# E17              1
# A24              1
# C50              1
# B42              1
# C148             1
# Name: count, Length: 148, dtype: int64

# %%
dfc.drop(columns=['PassengerId','Cabin'],inplace=True)

# %% [markdown]
# ## Soal 2.6 Melakukan Standarisasi kolom Fare, Age, dan FamilySize

# %%
for col in dfc[['Fare','Age','FamilySize']]:
    dfc[col] = (dfc[col] - dfc[col].mean()) / dfc[col].std()

# %% [markdown]
# ## Soal 2.7 Melakukan Pengecekan Korelasi untuk Feature Selection

# %%
plt.figure(figsize=(18,8))
sns.heatmap(dfc.corr(),annot=True,cmap='coolwarm') 
plt.show()

# %%
xa = dfc.drop(columns=['Title_Sir','Title_the Countess','Title_Lady','Survived']) # X alternatif yang tidak sesuai dengan soal di studi kasus
x = dfc[['Title_Dr','Title_Miss','Title_Mr','Title_Master','Sex_1','Pclass','FamilySize','Age','Fare','Embarked_Q','Embarked_S']]
y = dfc['Survived']

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title_Dr      891 non-null    int64
#  1   Title_Miss    891 non-null    int64
#  2   Title_Mr      891 non-null    int64
#  3   Title_Master  891 non-null    int64
#  4   Sex_1         891 non-null    int64
#  5   Pclass        891 non-null    int64
#  6   FamilySize    891 non-null    float64
#  7   Age           891 non-null    float64
#  8   Fare          891 non-null    float64
#  9   Embarked_Q    891 non-null    int64
#  10  Embarked_S    891 non-null    int64
# dtypes: float64(3), int64(8)
# memory usage: 76.7 KB

# %% [markdown]
# # 3. Modelling

# %% [markdown]
# ## Soal 3.1: Knn manual

# %% [markdown]
# ### KNN From scratch

# %%
def euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b) ** 2))

def manhattan_distance(a, b):
    return np.sum(np.abs(a - b))

def minkowski_distance(a, b, p):
    return np.sum(np.abs(a - b) ** p) ** (1 / p)

class KNeighborsClassifierManual:
    def __init__(self, n_neighbors=5, metric='euclidean', p=3):
        self.n_neighbors = n_neighbors
        self.metric = metric
        self.p = p

    def fit(self, X, y):
        self.X_train = X
        self.y_train = y

    def predict(self, X):
        predictions = [self._predict(x) for x in X]
        return np.array(predictions)
    
    def _predict(self, x):
        distances = [self._distance(x, x_train) for x_train in self.X_train]
        k_indices = np.argsort(distances)[:self.n_neighbors]
        k_nearest_labels = [self.y_train[i] for i in k_indices]
        most_common = np.bincount(k_nearest_labels).argmax()
        return most_common
    
    def _distance(self, a, b):
        if self.metric == 'euclidean':
            return euclidean_distance(a, b)
        elif self.metric == 'manhattan':
            return manhattan_distance(a, b)
        elif self.metric == 'minkowski':
            return minkowski_distance(a, b, self.p)
        else:
            raise ValueError(f"Unknown metric: {self.metric}")

# %% [markdown]
# ### Cross Validation

# %%
def cross_val(knn,x,y,cv=5):
    np.random.seed(42)
    indices = np.arange(x.shape[0])
    np.random.shuffle(indices)
    fold_sizes = np.full(cv,x.shape[0] // cv, dtype=int)
    fold_sizes[:x.shape[0] % cv] += 1
    current = 0
    scores = []
    
    for size in fold_sizes:
        start,stop = current, current + size
        test_idx = indices[start:stop]
        train_idx = np.concatenate([indices[:start],indices[stop:]])
        
        xtr = x[train_idx]
        ytr = y[train_idx]
        xte = x[test_idx]
        yte = y[test_idx]
        
        knn.fit(xtr,ytr)
        ypred = knn.predict(xte)
        acc = np.mean(ypred == yte) / len(yte)
        scores.append(acc)
        
    return np.array(scores)

# %% [markdown]
# ## Soal 3.2: GridSearch

# %%
def grid_search(xtr,ytr,param,cv=5):
    best_score = 0
    best_param = None
    for neighbor in param['n_neighbor']:
        for metric in param['metric']:
            for p in param.get('p',[3]):
                knn = KNeighborsClassifierManual(n_neighbors=neighbor,metric=metric,p=p)
                scores = cross_val(knn,xtr,ytr,cv=cv)
                mean_scores = scores.mean()
                if mean_scores > best_score:
                    best_score = mean_scores
                    best_param = {'n_neighbor':neighbor,'metric':metric,'p':p}
    return best_param,best_score

param = {
    'n_neighbor': [3,5,7,9,11],
    'metric': ['minkowski','euclidean','manhattan'],
    'p': [1,2,3,4,5]
}

best_param,best_score = grid_search(x.values,y.values,param,cv=5)
print(best_param)
# Out:
# {'n_neighbor': 11, 'metric': 'minkowski', 'p': 2}

# %% [markdown]
# ### Implementasi knn pada X

# %%
knn = KNeighborsClassifierManual(n_neighbors=11, metric='minkowski',p=1)
knn.fit(x.values, y)
knn_pred = knn.predict(x.values)

# %% [markdown]
# ### Implementasi knn pada X alternatif

# %%
param = {
    'n_neighbor': [3,5,7,9,11],
    'metric': ['minkowski','euclidean','manhattan'],
    'p': [1,2,3,4,5]
}

best_param,best_score = grid_search(xa.values,y.values,param,cv=5)
print(best_param)
# Out:
# {'n_neighbor': 5, 'metric': 'minkowski', 'p': 1}

# %%
knn_alt = KNeighborsClassifierManual(n_neighbors=7,metric='minkowski',p=1)
knn_alt.fit(xa.values,y)
knn_alt_pred = knn_alt.predict(xa.values)

# %% [markdown]
# ## Soal 3.3 Perbandingan model KNN dengan Logistic Regression

# %%
class LogisticRegressionManual:
    def __init__(self, learning_rate=0.01, n_iterations=1000):
        self.learning_rate = learning_rate
        self.n_iterations = n_iterations

    def sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def fit(self, X, y):
        self.m, self.n = X.shape
        self.weights = np.zeros(self.n)
        self.bias = 0

        for _ in range(self.n_iterations):
            linear_model = np.dot(X, self.weights) + self.bias
            y_predicted = self.sigmoid(linear_model)

            dw = (1 / self.m) * np.dot(X.T, (y_predicted - y))
            db = (1 / self.m) * np.sum(y_predicted - y)

            self.weights -= self.learning_rate * dw
            self.bias -= self.learning_rate * db

    def predict(self, X):
        linear_model = np.dot(X, self.weights) + self.bias
        y_predicted = self.sigmoid(linear_model)
        y_predicted_cls = [1 if i > 0.5 else 0 for i in y_predicted]
        return np.array(y_predicted_cls)

# %%
logreg = LogisticRegressionManual(learning_rate=0.01, n_iterations=1000)
logreg.fit(x.values, y.values)
logreg_pred = logreg.predict(x.values)

# %% [markdown]
# ## Soal 3.6: Penambahan data baru dan prediksi data tersebut

# %%
new_data = {
    "Title_Dr": 0,
    "Title_Miss": 1,
    "Title_Mr": 0,
    "Title_Master": 0,
    'Sex_1': 0,
    'Pclass': 3,
    'FamilySize': 0 + 1, #penumpang tunggal
    'Age': 21,
    'Fare': 8.5,
    'Embarked_Q': 0,
    'Embarked_S': 1,
}
new_data = pd.DataFrame([new_data])
new_data
# Out:
#    Title_Dr  Title_Miss  Title_Mr  Title_Master  Sex_1  Pclass  FamilySize  \
# 0         0           1         0             0      0       3           1
#
#    Age  Fare  Embarked_Q  Embarked_S
# 0   21   8.5           0           1

# %%
x
# Out:
#      Title_Dr  Title_Miss  Title_Mr  Title_Master  Sex_1  Pclass  FamilySize  \
# 0           0           0         0             0      0       3    0.179307
# 1           0           1         1             0      1       1    0.179307
# 2           0           1         1             0      1       3   -0.657147
# 3           0           1         1             0      1       1    0.179307
# 4           0           0         0             0      0       3   -0.657147
# ..        ...         ...       ...           ...    ...     ...         ...
# 886         0           0         0             0      0       2   -0.657147
# 887         0           1         1             0      1       1   -0.657147
# 888         0           1         1             0      1       3    1.852214
# 889         0           0         0             0      0       1   -0.657147
# 890         0           0         0             0      0       3   -0.657147
#
# ...

# %%
new_data['FamilySize'] = (new_data['FamilySize'] - dfc['FamilySize'].mean()) / dfc['FamilySize'].std()
new_data['Age'] = (new_data['Age'] - dfc['Age'].mean()) / dfc['Age'].std()
new_data['Fare'] = (new_data['Fare'] - dfc['Fare'].mean()) / dfc['Fare'].std()

# %%
new_data
# Out:
#    Title_Dr  Title_Miss  Title_Mr  Title_Master  Sex_1  Pclass  FamilySize  \
# 0         0           1         0             0      0       3         1.0
#
#     Age  Fare  Embarked_Q  Embarked_S
# 0  21.0   8.5           0           1

# %%
dfc['FamilySize']
# Out:
# 0      0.179307
# 1      0.179307
# 2     -0.657147
# 3      0.179307
# 4     -0.657147
#          ...
# 886   -0.657147
# 887   -0.657147
# 888    1.852214
# 889   -0.657147
# 890   -0.657147
# Name: FamilySize, Length: 891, dtype: float64

# %%
input_pred = knn.predict(new_data.values)
if input_pred == 0:
    print('Penumpang tidak selamat')
else:
    print('Penumpang selamat')
# Out:
# Penumpang tidak selamat

# %% [markdown]
# # 4. Evaluasi

# %% [markdown]
# ## Pengecekan Akurasi tiap model (KNN, KNN Alternative, Logistic Regression)

# %%
accuracy = np.mean(knn_pred == y)
print(f'Akurasi Model KNN {accuracy}')
# Out:
# Akurasi Model KNN 0.8529741863075196

# %%
accuracy = np.mean(knn_alt_pred == y)
print(f'Akurasi Model KNN Alternatif {accuracy}')
# Out:
# Akurasi Model KNN Alternatif 0.8574635241301908

# %%
logreg_acc = np.mean(logreg_pred == y)
print(f'Logistic Regression Manual Accuracy: {logreg_acc}')
# Out:
# Logistic Regression Manual Accuracy: 0.8035914702581369

# %% [markdown]
# ## Pengecekan Precision,Recall,F1, dan Confusion Matrix

# %%
def precision_recall_f1_support(y_true, y_pred, average=None):
    labels = np.unique(np.concatenate((y_true, y_pred)))
    report = {}
    
    for label in labels:
        tp = sum((y_true[i] == label) and (y_pred[i] == label) for i in range(len(y_true)))
        fp = sum((y_true[i] != label) and (y_pred[i] == label) for i in range(len(y_true)))
        fn = sum((y_true[i] == label) and (y_pred[i] != label) for i in range(len(y_true)))
        tn = sum((y_true[i] != label) and (y_pred[i] != label) for i in range(len(y_true)))

        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        support = sum(y == label for y in y_true)

        report[label] = {
            'precision': precision,
            'recall': recall,
            'f1-score': f1_score,
            'support': support
        }

    if average == 'macro':
        avg_precision = sum(report[label]['precision'] for label in labels) / len(labels)
        avg_recall = sum(report[label]['recall'] for label in labels) / len(labels)
        avg_f1_score = sum(report[label]['f1-score'] for label in labels) / len(labels)
        avg_support = sum(report[label]['support'] for label in labels)
        
        report['macro avg'] = {
            'precision': avg_precision,
            'recall': avg_recall,
            'f1-score': avg_f1_score,
            'support': avg_support
        }
    
    return report

def print_classification_report(report):
    print(f"{'Label':<10} {'Precision':<10} {'Recall':<10} {'F1-Score':<10} {'Support':<10}")
    print("="*50)
    for label, metrics in report.items():
        print(f"{label:<10} {metrics['precision']:<10.2f} {metrics['recall']:<10.2f} {metrics['f1-score']:<10.2f} {metrics['support']:<10}")

print('classification report model KNN')
report_knn = precision_recall_f1_support(y, knn_pred, average='macro')
print_classification_report(report_knn)
# Out:
# classification report model KNN
# Label      Precision  Recall     F1-Score   Support
# ...
# 0          0.85       0.93       0.89       549
# 1          0.87       0.73       0.79       342
# macro avg  0.86       0.83       0.84       891

# %%
print('classification report model KNN alternatif')
report_knn = precision_recall_f1_support(y, knn_alt_pred, average='macro')
print_classification_report(report_knn)
# Out:
# classification report model KNN alternatif
# Label      Precision  Recall     F1-Score   Support
# ...
# 0          0.87       0.90       0.89       549
# 1          0.83       0.79       0.81       342
# macro avg  0.85       0.84       0.85       891

# %%
print('classification report model Logistic Regression')
report_knn = precision_recall_f1_support(y, logreg_pred, average='macro')
print_classification_report(report_knn)
# Out:
# classification report model Logistic Regression
# Label      Precision  Recall     F1-Score   Support
# ...
# 0          0.82       0.87       0.85       549
# 1          0.77       0.70       0.73       342
# macro avg  0.80       0.78       0.79       891

# %%
def confusion_matrix(yte,ypred):
    tp = fp = tn = fn = 0 
    for true,pred in zip(yte,ypred):
        if true == 1 and pred == 1:
            tp += 1
        elif true == 1 and pred == 0:
            fp += 1
        elif true == 0 and pred == 0:
            tn += 1
        elif true == 0 and pred == 1:
            fn += 1
            
    confusion_matrix = np.array([[tn,fp],[fn,tp]])
        
    fig, ax = plt.subplots()
    ax.matshow(confusion_matrix,cmap='coolwarm',alpha=0.6)
    for i in range(confusion_matrix.shape[0]):
        for j in range(confusion_matrix.shape[1]):
            ax.text(x=j,y=i,s=confusion_matrix[i,j],va='center',ha='center')
                
    
    plt.xlabel('Prediksi')
    plt.ylabel('Asli')
    plt.xticks([0,1], ['Tidak Selamat','Selamat'])
    plt.yticks([0,1], ['Tidak Selamat','Selamat'])
    plt.show()

print("Confusion Matrix Model KNN")
confusion_matrix(y,knn_pred)
# Out:
# Confusion Matrix Model KNN

# %%
print("Confusion Matrix Model KNN alternatif")
confusion_matrix(y,knn_alt_pred)
# Out:
# Confusion Matrix Model KNN alternatif

# %%
print("Confusion Matrix Model Logistic Regression")
confusion_matrix(y,logreg_pred)
# Out:
# Confusion Matrix Model Logistic Regression

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=dfc, x=dfc['Title_Master'], hue='Sex_1')
plt.legend(['Perempuan','Laki-Laki'])
plt.show()

# %% [markdown]
# # Kesimpulan:
#
# ## Model
# 1. **Model KNN (Dan KNN Alternatif)** dapat **memprediksi** orang yang **tidak selamat dengan baik**, namun terkadang memprediksi **orang yang tidak selamat sebagai orang yang selamat**.
# 2. **Model Logistic Regression tertinggal dibelakang kedua Model KNN** baik secara Confusion matrix maupun Akurasi
# 3. **Model Sudah dapat Digunakan**, karena sudah berada dalam threshold akurasi 85-93%,
#
# ## Data
# 1. **Sebaiknya jangan menaiki titanic (Kecuali penumpang adalah anak-anak atau perempuan)**, karena jika terjadi kecelakaan, maka yang **diselamatkan pertama adalah anak-anak dan perempuan**, serta orang-orang penting di titanic **(Sir,Lady,Countess)**
#
# 2. **Jika memang harus menaiki titanic, sebaiknya membeli tiket business class (2) atau first class (1),** serta **selalu waspada dan tidak terlalu terbawa suasana kemegahan** di titanic.
#
# 3. Diusahakan **membeli tiket termurah yang ada**, karena **tiket yang lebih mahal tidak menjamin keselamatan penumpang**.
#
# 4. Dari **pihak titanic mungkin ingin mengevaluasi kembali struktur kapal serta rute yang diambil** oleh kapal, karena rute dari kota tertentu memiliki tingkat keselamatan yang lebih tinggi, kami menduga salah satu faktornya adalah seberapa dekat tempat tenggelam ke titik selamat (daratan, pelabuhan).
#
# 5. Kami **tidak menemukan hubungan** antara **tingkat keselamatan penumpang** dengan **seberapa bagus sebuah cabin** yang dimiliki oleh penumpang. **Namun, kita menemukan bahwa penumpang yang memiliki cabin memiliki rasio selamat yang lebih tinggi dibanding tidak**. Serta, bahwa penumpang tiket biasa cenderung tidak memiliki cabin.
#
# 6. Jabatan atau Title seseorang menentukan
#
# 7. Kita dapat melihat dari visualisasi kolom Embarked bahwa **banyak kapal yang berangkat dari pelabuhan Southhampton, dan dia juga pelabuhan yang memiliki rasio kematian tertinggi** dibanding dua pelabuhan lain. Selain itu, kapal dari **pelabuhan Cherbourgh memiliki rasio keselamatan yang positif,** menunjukkan bahwa kapal titanic kemungkinan **tenggelam tidak jauh dari pelabuhan,** dan bahwa kapal dari **Cherbourgh memiliki kesiapan yang lebih baik ketika ada kondisi darurat.**

# %% [markdown]
# pak amri khawatir bahwa kita tidak dapat mempresent secara detail, jadi juri tidak terlalu mengerti kalau bisa present sebaik ini, bisa saja sekedar mengumpulkan projek, nanti haru smengawasi situasi juri apakah membawa formulir atau tidak
